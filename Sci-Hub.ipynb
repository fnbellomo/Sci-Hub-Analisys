# %% [markdown]
# # *Sci-Hub server log data analysis*
#
# ### *John Bohannon, Science magazine*

# %% [markdown]
# This Notebook will help you process the 6 months of raw server log data provided by Sci-Hub to Science magazine in March 2016.
#
# **Science article:**
#
# http://www.sciencemag.org/news/2016/04/whos-downloading-pirated-papers-everyone
#
# **Data set:**
#
# http://dx.doi.org/10.5061/dryad.q447c

# %%
import pandas as pd
import numpy as np

# %%
months = ("sep2015", "oct2015", "nov2015", "dec2015", "jan2016", "feb2016")

# %%
# %mkdir "scihub_data_temp"

# %% [markdown]
# **We will need CrossRef's database of DOI prefixes to identify publishers from the DOIs.**
#
# http://www.crossref.org/06members/50go-live.html
#
# **Don't worry, I scraped all that for you:**

# %%
journal_DOIs = pd.read_csv("publisher_DOI_prefixes.csv", index_col = 0)
journal_DOIs.head()
# Out:
#                                                 Name    Prefix   Date Joined  \
# 0  Povolzhskiy State University of Telecommunicat...  10.18469           NaN
# 1                   "Henri Coanda" Air Force Academy  10.19062           NaN
# 2                                   123Doc Education   10.7579  May 16, 2012
# 3  21st Century COE Program (Toplogical Science a...   10.3731  Nov 20, 2007
# 4         21st Century Political Science Association  10.17937           NaN
#
#   Date of \nLast Deposit Date of \nLast Query
# 0           Dec 16, 2015              unknown
# 1           Jan 05, 2016              unknown
# 2                unknown              unknown
# 3                unknown              unknown
# 4           Sep 14, 2015              unknown

# %% [markdown]
# **Holding all months of raw data in memory is a bit much for most laptop computers, so let's process each month separately to generate aggregate data.**

# %%
def process_data(month):
    
    # load the file as a dataframe
    path = "scihub_data/"
    filename = month + ".tab"
    with open(path + filename, "r") as f:
        data = pd.read_table(f)

    # this is the format of the columns
    data.columns = ["date","doi","IP_code","country","city","coords"]

    # create a few more useful columns
    data[["latitude", "longitude"]] = data.coords.str.split(",", expand = True)
    data["prefix"] = data.dropna(subset = ["doi"]).doi.apply(lambda x: x.split("/")[0])

    # group by DOI prefix and count total downloads for each
    publishers = data.dropna(subset = ["prefix"]).groupby("prefix").count()
    publishers = publishers.sort_values(by = "date", ascending = False).date
    publishers = publishers.reset_index()
    publishers.columns = ["prefix","downloads"]

    # translate those DOI prefixes into publisher names using the CrossRef data
    data_publishers = pd.merge(publishers, journal_DOIs[["Prefix","Name"]],
                               left_on = "prefix", right_on = "Prefix", how = "left")
    data_publishers[["prefix","downloads","Name"]].to_csv("scihub_data_temp/%s_publishers.csv" %(month))

    # calculate the 100 most downloaded DOIs of the month
    top100_doi = data.groupby("doi").count().sort_values(by = "date", ascending = False)[:100].date
    top100_doi.name = "downloads"
    top100_doi.to_csv("scihub_data_temp/%s_top100_doi.csv" %month, header = "downloads")

# %%
for month in months:
    print(month)
    process_data(month)
# Out:
# sep2015
# oct2015
# nov2015
# dec2015
# jan2016
# feb2016

# %% [markdown]
# **Now let's see the big picture, starting with the publishers...**

# %%
publishers_by_month = [pd.read_csv("scihub_data_temp/" + i + "_publishers.csv") for i in months]
for i in publishers_by_month:
    print(len(i))
# Out:
# 1095
# 1216
# 1039
# 1166
# 1223
# 1405

# %%
all_publishers = pd.concat(publishers_by_month)

# %%
all_publishers = all_publishers.groupby("Name").sum().downloads.sort_values(ascending = False)
all_publishers.head()
# Out:
# Name
# Elsevier                                             9296485
# Springer-Verlag                                      5261574
# Nature Publishing Group                              2243762
# Institute of Electrical and Electronics Engineers    2138064
# American Chemical Society                            1871933
# Name: downloads, dtype: int64

# %%
sum([int(i[i.Name == "Elsevier"].downloads) for i in publishers_by_month])
# Out:
# 9296485

# %% [markdown]
# **Yep, that checks out. Nearly 10 million Elsevier downloads in 6 months.**

# %%
all_publishers.to_csv("downloads_by_publishers.csv", header = ["downloads"])

# %% [markdown]
# **Next let's get a list of most downloaded papers across the 6-month period.**

# %%
all_papers = pd.concat([pd.read_csv("scihub_data_temp/" + i + "_top100_doi.csv") for i in months])

# %%
all_papers.groupby("doi").count().sort_values(by = "downloads",ascending = False).head()
# Out:
#                        downloads
# doi
# 10.1038/nbt.2842               6
# 10.1038/nmat1849               6
# 10.1109/TKDE.2013.109          6
# 10.1016/j                      6
# 10.1002/14651858               6

# %% [markdown]
# **Plenty of papers are in the top100 across all 6 months. Let's see what the most downloaded paper is across the entire time period...**

# %%
top25_doi = all_papers.groupby("doi").sum().downloads.sort_values(ascending = False)[:25]
top25_doi
# Out:
# doi
# 10.1007/978-1-4419-9716-6_11              7988
# 10.1056/NEJMoa1402121                     6063
# 10.1116/1.4904970                         2987
# 10.1103/PhysRevB.63.224204                2890
# 10.1182/asheducation-2015.1.8             2528
# 10.4028/www.scientific.net/AMM.7-8.159    2266
# 10.1111/j.1365-277X.2004.00520.x          2241
# 10.1002/pmic.200600525                    2166
# 10.1161/CIRCRESAHA.117.306290             1977
# 10.1002/3527603433.ch3                    1704
# 10.1002/smll.201002009                    1687
# 10.1007/s10832-012-9736-1                 1474
# 10.1158/1541-7786.MCR-14-0590             1182
# 10.1038/nmat3258                          1163
# 10.1016/j                                 1138
# 10.1109/ISPASS.2015.7095803               1122
# 10.1017/S0034670512001088                 1121
# 10.2514/3.59819                           1083
# 10.1002/14651858                           973
# 10.1057/9781137555298                      962
# 10.1128/JB.02242-14                        958
# 10.2478/s11696-011-0110-6                  935
# 10.1109/ISNE.2014.6839382                  929
# 10.1007/978-3-319-28658-7_55               851
# 10.1038/nmat1849                           850
# Name: downloads, dtype: int64

# %%
data_list = list()
for month in months:
    print(month)
    datafile = "scihub_data/" + month + ".tab"
    with open(datafile, "r") as f:
        this_month = pd.read_table(f)
        this_month.columns = ["date", "doi", "IP_code", "country", "city", "coords"]
        data_list.append(this_month.groupby("doi").count().date)
# Out:
# sep2015
# oct2015
# nov2015
# dec2015
# jan2016
# feb2016

# %%
data = data_list[0]
for i in data_list[1:]:
    data = data.add(i, fill_value = 0)
data.head()
# Out:
# doi
# .1991.236                   1
# .blo.0000132404.30139.f2    1
# 000441-184101000-00011      1
# 002-9610(02)00865-6         1
# 003-9993(96)90138-0         1
# Name: date, dtype: float64

# %%
data.name = "downloads"
data = data.sort_values(ascending = False)
data.head()
# Out:
# doi
# 10.1007/978-1-4419-9716-6_11     7988
# 10.1056/NEJMoa1402121            6117
# 10.1116/1.4904970                2991
# 10.1103/PhysRevB.63.224204       2890
# 10.1182/asheducation-2015.1.8    2528
# Name: downloads, dtype: float64

# %% [markdown]
# **Note that some DOIs are invalid, due to typos from the Sci-Hub users or, in the case of 10.1182/asheducation-2015.1.8, because a website listed the wrong DOI.**

# %%
data[:100].astype(int).to_csv("top100_downloads_by_DOI.csv", header = "downloads")

# %%
import requests, json
from pandas.io.json import json_normalize

def get_top25_metadata(doi):
    fields = ["title", "type", "publisher","container-title", "subject", "published-print.date-parts"]
    metadata = dict([(i, None) for i in fields])
    metadata["doi"] = doi
    try:
        url = "http://dx.doi.org/" + doi
        headers = {"accept": "application/citeproc+json"}
        r = requests.get(url, headers = headers)
        full_metadata = json_normalize(json.loads(r.text))
        for i in fields:
            if i in full_metadata.columns:
                metadata[i] = full_metadata.iloc[0][i]
    except:
        pass
    return metadata

# %%
get_top25_metadata("10.1007/978-1-4419-9716-6_11")
# Out:
# {'container-title': 'Structural Dynamics and Renewable Energy, Volume 1',
#  'doi': '10.1007/978-1-4419-9716-6_11',
#  'published-print.date-parts': [[2011]],
#  'publisher': 'Springer Science + Business Media',
#  'subject': None,
#  'title': 'Full-scale modal wind turbine tests: comparing shaker excitation with wind excitation',
#  'type': 'book-chapter'}

# %%
top25 = pd.DataFrame([get_top25_metadata(i) for i in data[:25].index.values])
top25
# Out:
#                                       container-title  \
# 0   Structural Dynamics and Renewable Energy, Volu...
# 1                     New England Journal of Medicine
# 2                             J. Vac. Sci. Technol. B
# 3                                        Phys. Rev. B
# 4                                                None
# 5                                                 AMM
# 6            Journal of Human Nutrition and Dietetics
# 7                                          Proteomics
# 8                                Circulation Research
# 9                                               Small
# 10           Protein Synthesis and Ribosome Structure
# 11                                     J Electroceram
# 12                                   Nature Materials
# 13                          Molecular Cancer Research
# 14                                               None
# 15  2015 IEEE International Symposium on Performan...
# 16                             The Review of Politics
# 17                                Journal of Aircraft
# 18                                               None
# 19                            Journal of Bacteriology
# 20                                               None
# 21  2014 International Symposium on Next-Generatio...
# 22                                    Chemical Papers
# 23      Advances in Intelligent Systems and Computing
# 24                                   Nature Materials
#
#                                        doi published-print.date-parts  \
# 0             10.1007/978-1-4419-9716-6_11                   [[2011]]
# 1                    10.1056/NEJMoa1402121            [[2015, 6, 25]]
# 2                        10.1116/1.4904970                [[2015, 5]]
# 3               10.1103/PhysRevB.63.224204                       None
# 4            10.1182/asheducation-2015.1.8                       None
# 5   10.4028/www.scientific.net/AMM.7-8.159                       None
# 6         10.1111/j.1365-277X.2004.00520.x                [[2004, 6]]
# 7                   10.1002/pmic.200600525                [[2007, 1]]
# 8            10.1161/CIRCRESAHA.117.306290             [[2015, 7, 3]]
# 9                   10.1002/smll.201002009            [[2011, 7, 18]]
# 10                  10.1002/3527603433.ch3                       None
# 11               10.1007/s10832-012-9736-1                [[2012, 8]]
# 12                        10.1038/nmat3258                       None
# 13           10.1158/1541-7786.MCR-14-0590             [[2015, 8, 1]]
# 14                               10.1016/j                       None
# 15             10.1109/ISPASS.2015.7095803                [[2015, 3]]
# 16               10.1017/S0034670512001088               [[2013, 12]]
# 17                         10.2514/3.59819                [[1975, 4]]
# 18                        10.1002/14651858                       None
# 19                     10.1128/JB.02242-14           [[2014, 11, 15]]
# 20                   10.1057/9781137555298                       None
# 21               10.1109/ISNE.2014.6839382                [[2014, 5]]
# 22               10.2478/s11696-011-0110-6             [[2012, 1, 1]]
# 23            10.1007/978-3-319-28658-7_55                   [[2016]]
# 24                        10.1038/nmat1849                [[2007, 3]]
#
#                                             publisher  \
# 0                   Springer Science + Business Media
# 1          New England Journal of Medicine (NEJM/MMS)
# 2                             American Vacuum Society
# 3                     American Physical Society (APS)
# 4                                                None
# 5                             Trans Tech Publications
# 6                                     Wiley-Blackwell
# 7                                     Wiley-Blackwell
# 8           Ovid Technologies (Wolters Kluwer Health)
# 9                                     Wiley-Blackwell
# 10                                    Wiley-Blackwell
# 11                  Springer Science + Business Media
# 12                            Nature Publishing Group
# 13    American Association for Cancer Research (AACR)
# 14                                               None
# 15  Institute of Electrical & Electronics Engineer...
# 16                   Cambridge University Press (CUP)
# 17  American Institute of Aeronautics and Astronau...
# 18                                    Wiley-Blackwell
# 19                  American Society for Microbiology
# 20                                               None
# 21  Institute of Electrical & Electronics Engineer...
# 22                             Walter de Gruyter GmbH
# 23                  Springer Science + Business Media
# 24                            Nature Publishing Group
#
#                                               subject  \
# 0                                                None
# 1                                     [Medicine(all)]
# 2                                                None
# 3                          [Condensed Matter Physics]
# 4                                                None
# 5                                                None
# 6   [Nutrition and Dietetics, Medicine (miscellane...
# 7                   [Biochemistry, Molecular Biology]
# 8   [Physiology, Cardiology and Cardiovascular Med...
# 9                                     [Medicine(all)]
# 10                                               None
# 11  [Electrical and Electronic Engineering, Materi...
# 12  [Mechanical Engineering, Materials Science(all...
# 13     [Cancer Research, Oncology, Molecular Biology]
# 14                                               None
# 15                                               None
# 16  [Political Science and International Relations...
# 17                            [Aerospace Engineering]
# 18                                               None
# 19                  [Molecular Biology, Microbiology]
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24  [Mechanical Engineering, Materials Science(all...
#
#                                                 title                 type
# 0   Full-scale modal wind turbine tests: comparing...         book-chapter
# 1   Comprehensive, Integrative Genomic Analysis of...      journal-article
# 2   Photosensitive field emission study of SnS2 na...      journal-article
# 3   Griffiths effects and quantum critical points ...      journal-article
# 4                                                None                 None
# 5   Monitoring the Evolution of Fatigue in Corruga...      journal-article
# 6   Intentional mis-reporting of food consumption ...      journal-article
# 7   Conifer defense against insects: Proteome anal...      journal-article
# 8   Efficient Gene Disruption in Cultured Primary ...      journal-article
# 9   Graphene-Based Materials: Synthesis, Character...      journal-article
# 10                                  Ribosome Assembly         book-chapter
# 11  Experimental model identification and vibratio...      journal-article
# 12            Heavy fermions: Dimensions are critical      journal-article
# 13  Colorectal Carcinogenesis: Connecting K-RAS-In...      journal-article
# 14                                               None                 None
# 15  Nyami: a synthesizable GPU architectural model...  proceedings-article
# 16  Between Logic and Psychology: The Links betwee...      journal-article
# 17  Distortion-Induced Vibration in Fan and Compre...      journal-article
# 18            Cochrane Database of Systematic Reviews       reference-book
# 19  Retraction for Ramos et al., The Second RNA Ch...      journal-article
# 20                                               None                 None
# 21  A pure logic CMOS based low power non-volatile...  proceedings-article
# 22  Nanostructured electrocatalysts immobilised on...      journal-article
# 23  Detection of Copy-Move Forgery in Images Using...         book-chapter
# 24                               The rise of graphene      journal-article

# %%
top25.to_csv("top25_papers.csv")

# %% [markdown]
# **Now let's look at the geography of Sci-Hub downloads.**

# %%
def get_country_data(month):
    path = "scihub_data/"
    filename = month + ".tab"
    with open(path + filename, "r") as f:
        data = pd.read_table(f)
        data.columns = ["date", "doi", "IP_code", "country", "city", "coords"]
        data = data[["country", "date"]]
        data = data.groupby("country").count()
    return data

# %%
data_list = [get_country_data(month) for month in months]

# %%
by_country = data_list[0]
for i in data_list[1:]:
    by_country = by_country.add(i)
data_list = None
by_country = by_country.sort_values(by = "date", ascending = False)
by_country.head()
# Out:
#                   date
# country
# China          4456076
# India          3414581
# Iran           2631035
# Russia         1521434
# United States  1150963

# %%
by_country.columns = ["downloads"]

# %%
by_country.to_csv("downloads_by_country.csv")

# %% [markdown]
# **Now to get downloads by lat/lon coordinates...**

# %%
def get_cities(month):
    filepath = "scihub_data/" + month + ".tab"
    with open(filepath, "r") as f:
        data = pd.read_table(f)
        data.columns = ["date","doi","IP_code","country","city","coords"]
        data = data.groupby(["coords","city","country"]).count()
        data = data.rename(columns = {"date":"downloads"})
        return data["downloads"]

# %%
downloads_by_coords = get_cities(months[0])
for month in months[1:]:
    print(month)
    downloads_by_coords = downloads_by_coords.add(get_cities(month), fill_value = 0)
# Out:
# oct2015
# nov2015
# dec2015
# jan2016
# feb2016

# %%
len(downloads_by_coords)
# Out:
# 21906

# %% [markdown]
# **So there are about 22,000 locations with unique triples of (lat/lon, city name, country name).**

# %%
downloads_by_coords = downloads_by_coords.reset_index()
downloads_by_coords.columns = ["coords","city","country","downloads"]

# %%
downloads_by_coords.head()
# Out:
#                    coords                            city  country  downloads
# 0  -0.1806532,-78.4678382                           Quito  Ecuador      83065
# 1  -0.2389045,-79.1774268  Santo Domingo de los Colorados  Ecuador        258
# 2    -0.3030988,36.080026                          Nakuru    Kenya         13
# 3  -0.3301412,-78.4499915                       Sangolquí  Ecuador          2
# 4  -0.9457944,-47.1256835                       Primavera   Brazil         10

# %% [markdown]
# **Some coords cluster to the same city/country. Let's find them...**

# %%
by_coords = downloads_by_coords.reset_index()
coord_dupes = by_coords[by_coords.duplicated(subset=["city","country"])]
coord_dupes
# Out:
#        index                   coords             city         country  \
# 152      152  -15.7941874,-47.8825852         Brasília          Brazil
# 154      154   -15.813415,-48.1044183         Brasília          Brazil
# 156      156  -15.8711088,-47.9709785         Brasília          Brazil
# 157      157  -15.8729537,-48.0163953         Brasília          Brazil
# 604      604  -22.2459149,-43.7068952          Valença          Brazil
# 781      781  -23.2286098,-51.5877624     Pitangueiras          Brazil
# 934      934   -25.503107,-49.2368575         Curitiba          Brazil
# 996      996  -26.4803234,-51.9908764           Palmas          Brazil
# 21674  21674  61.2180556,-149.9002778        Anchorage   United States
# 21751  21751    65.1762807,25.3531972             Oulu         Finland
# 21771  21771    67.6107356,33.6724006          Kirovsk          Russia
# 21774  21774    67.9438833,34.5496594            Revda          Russia
#
#        downloads
# 152        55878
# 154          527
# 156            5
# 157          544
# 604           50
# 781           45
# 934          131
# 996           17
# 1154           7
# 1588          35
# 1597          24
# 1623          69
# 1702          66
# 1727          72
# 1742          38
# 1796          79
# 1857         202
# 1859        1982
# 1866        1173
# 1869      165779
# 1871        2967
# 1873          67
# 1875         703
# 1881        1055
# 1883         453
# 1885           9
# 1891         885
# 1893         107
# 1895          20
# 1896         555
# ...          ...
# 18117          8
# 18237          1
# 18285         65
# 18502          1
# 18992       2311
# 19057         10
# 19410          1
# 19426         23
# 19497       2906
# 19836          2
# 20131          4
# 20361          2
# 20393         27
# 20396      63047
# 20599        969
# 20619          6
# 20649         28
# 20674         10
# 20770        105
# 21230       1208
# 21252        159
# 21341          2
# 21348       2562
# 21598       8503
# 21644         22
# 21660          2
# 21674        181
# 21751        287
# 21771        665
# 21774          5
#
# [1352 rows x 5 columns]

# %% [markdown]
# **Yeah look at that. Many Sci-Hub user IP addresses clustered to different lat/lon coordinates within the same city, probably because the Google Maps API treats big cities as supersets of several smaller cities. We'll need to pull out the lower-level "administrative_area_level" names using Google Maps...**

# %% [markdown]
# **From here to the end of this Notebook is data-wrangling I needed to build the map that features in the Science article. You probably don't need any of this for your own analyses. The code above gets you to the starting point.**

# %%
import requests, json
from pandas.io.json import json_normalize

# You will need to register with Google Maps and get your own free API key
# https://developers.google.com/maps/documentation/javascript/get-api-key
API_KEY = "AjZaSyCaecKeKEr9NEv4zXaPzVVSds1FLTrtM4x"

def get_admin(coords, country):
    url = "https://maps.googleapis.com/maps/api/geocode/json?key=%s&latlng=%s" %(API_KEY, coords)
    r = requests.get(url)
    data = json_normalize(json.loads(r.text)["results"], "address_components")
    if country == "United States":
        level = "administrative_area_level_1"
    else:
        level = "administrative_area_level_4"
    return data[data.types.map(lambda x: level in x)]["short_name"].iloc[0]

# %%
get_admin("-15.813415,-48.1044183", "Brazil")
# Out:
# 'Ceilândia'

# %%
with open("downloads_by_coords.csv") as f:
    by_coords = pd.read_csv(f)
by_coords.head()
# Out:
#                    coords                            city  country  downloads
# 0   -0.0917016,34.7679568                          Kisumu    Kenya          5
# 1  -0.1806532,-78.4678382                           Quito  Ecuador      83065
# 2  -0.2389045,-79.1774268  Santo Domingo de los Colorados  Ecuador        258
# 3    -0.3030988,36.080026                          Nakuru    Kenya         13
# 4  -0.3301412,-78.4499915                       Sangolquí  Ecuador          2

# %%
ambiguous = by_coords[by_coords.duplicated(["city","country"], keep = False)].copy()
ambiguous
# Out:
#                         coords           city         country  downloads
# 18      -1.4557549,-48.4901799          Belém          Brazil      12724
# 31      -10.249091,-48.3242858         Palmas          Brazil        739
# 38     -10.6872332,-37.4329352      Itabaiana          Brazil        511
# 109     -13.370017,-39.0720559        Valença          Brazil         82
# 21660  60.7922222,-161.7558333         Bethel   United States          2
# 21674  61.2180556,-149.9002778      Anchorage   United States        181
# 21749    65.0120888,25.4650773           Oulu         Finland        530
# 21751    65.1762807,25.3531972           Oulu         Finland        287
# 21771    67.6107356,33.6724006        Kirovsk          Russia        665
# 21774    67.9438833,34.5496594          Revda          Russia          5
#
# [2106 rows x 4 columns]

# %% [markdown]
# **So we have 2106 city names duplicated within countries...**

# %%
ambiguous[ambiguous.city == "Sterling"]
# Out:
#                         coords      city        country  downloads
# 6890    38.2100111,-98.2070059  Sterling  United States         11
# 7367    39.0026518,-77.3956004  Sterling  United States         25
# 7373    39.0066993,-77.4291298  Sterling  United States          1
# 9694     41.788642,-89.6962194  Sterling  United States          1
# 21644  60.5372222,-150.7647222  Sterling  United States         22

# %% [markdown]
# **For the US, we want the state, which is administrative_area_level_1 in the Google Maps JSON.**

# %%
get_admin("39.0026518,-77.3956004", "United States")
# Out:
# 'VA'

# %%
US_cities = ambiguous[ambiguous.country == "United States"].copy()
US_coords = US_cities["coords"].tolist()
get_admin(US_coords[0], "United States")
# Out:
# 'FL'

# %%
US_states = dict()

# %%
import sys

total = len(US_coords)
fails = list()
for n,i in enumerate(US_coords):
    sys.stdout.write("%s\t%s" %(total - n, len(fails)))
    if i not in US_states:
        try:
            US_states[i] = get_admin(i, "United States")
        except:
            fails.append(i)
    sys.stdout.flush()
    sys.stdout.write('\r')
print("%s\t%s" %(total - n, len(fails)))
# Out:
# 1	0

# %%
len(set(US_states.values()))
# Out:
# 50

# %% [markdown]
# **That takes care of the US states. Now to deal with non-US cities.**

# %%
ambiguous["admin"] = pd.Series()

# %%
ambiguous.tail()
# Out:
#                         coords       city        country  downloads  admin
# 21674  61.2180556,-149.9002778  Anchorage  United States        181    NaN
# 21749    65.0120888,25.4650773       Oulu        Finland        530    NaN
# 21751    65.1762807,25.3531972       Oulu        Finland        287    NaN
# 21771    67.6107356,33.6724006    Kirovsk         Russia        665    NaN
# 21774    67.9438833,34.5496594      Revda         Russia          5    NaN

# %%
non_US_cities = ambiguous[ambiguous.country != "United States"].copy()
non_US_coords = non_US_cities["coords"].tolist()
len(non_US_coords)
# Out:
# 363

# %% [markdown]
# **Not too bad. Just 363 non-US locations to deal with.**

# %%
import requests, json
from pandas.io.json import json_normalize

# You will need to register with Google Maps and get your own free API key
# https://developers.google.com/maps/documentation/javascript/get-api-key
API_KEY = "AjZaSyCaecKeKEr9NEv4zXaPzVVSds1FLTrtM4x"

def get_non_US_admin(coords):
    url = "https://maps.googleapis.com/maps/api/geocode/json?key=%s&latlng=%s" %(API_KEY, coords)
    r = requests.get(url)
    data = json_normalize(json.loads(r.text)["results"], "address_components")
    try:
        level = "administrative_area_level_4"
        return data[data.types.map(lambda x: level in x)]["short_name"].iloc[0]
    except:
        try:
            level = "administrative_area_level_3"
            return data[data.types.map(lambda x: level in x)]["short_name"].iloc[0]
        except:
            try:
                level = "administrative_area_level_2"
                return data[data.types.map(lambda x: level in x)]["short_name"].iloc[0]
            except:
                level = "locality"
                return data[data.types.map(lambda x: level in x)]["short_name"].iloc[0]

get_non_US_admin("65.0120888,25.4650773")
# Out:
# 'Oulu'

# %%
non_US_cities = dict()

# %% [markdown]
# **I started running into the 2500 queries/day limit, requiring multiple fresh API keys. So I'm keeping track of that with error messaging below. Loading the results into a dict as we go allows this to fail gracefully and always pick up where it left off.**

# %%
import time

total = len(non_US_coords)
fails = list()
for n,i in enumerate(non_US_coords):
    time.sleep(0.15)
    sys.stdout.write("%s\t%s" %(total - n, len(fails)))
    if i not in non_US_cities:
        try:
            result = get_non_US_admin(i)
            if result == "OVER_QUERY_LIMIT":
                print("OVER_QUERY_LIMIT")
                break
            else:
                non_US_cities[i] = result
        except:
            fails.append(i)
    sys.stdout.flush()
    sys.stdout.write('\r')
print("%s\t%s" %(total - n, len(fails)))
# Out:
# 1	73

# %%
coords_and_areas = US_states.copy()
for k,v in non_US_cities.items():
    coords_and_areas[k] = v
len(coords_and_areas)
# Out:
# 2033

# %%
coords = "45.83316,5.096755"
url = "https://maps.googleapis.com/maps/api/geocode/json?key=%s&latlng=%s" %(API_KEY, coords)
r = requests.get(url)
data = json_normalize(json.loads(r.text)["results"], "address_components")
data[data.types.map(lambda x: "locality" in x)]["short_name"].iloc[0]
# Out:
# 'Balan'

# %%
dupes = pd.Series(non_US_cities)[pd.Series(non_US_cities).duplicated(keep=False)].sort_values()
dupes
# Out:
# 45.83316,5.096755                         Ain
# 46.2127949,5.6642068                      Ain
# 38.7973239,-9.3432155               Algueirão
# 38.8123144,-9.3402312               Algueirão
# 38.7012207,-8.927294                  Atalaia
# 39.2311814,-9.3284683                 Atalaia
# -1.4557549,-48.4901799                  Belém
# -6.6956001,-35.5355783                  Belém
# 53.8175053,-3.0356748               Blackpool
# 53.8174245,-3.0352872               Blackpool
# -22.1631542,-42.4257912            Bom Jardim
# -7.7973604,-35.5787115             Bom Jardim
# -8.4892195,-36.2374768           Cachoeirinha
# -29.9477228,-51.1021166          Cachoeirinha
# 48.4264828,-123.3234659               Capital
# 48.4284207,-123.3656444               Capital
# 48.4442943,-123.4297652               Capital
# 49.8879519,-119.4960106      Central Okanagan
# 49.8887748,-119.4591495      Central Okanagan
# 13.0826802,80.2707184                 Chennai
# 13.0587471,80.254435                  Chennai
# 51.454513,-2.58791            City of Bristol
# 51.4454012,-2.5456095         City of Bristol
# 50.0379326,8.5621518                       DA
# 50.1109221,8.6821267                       DA
# 40.6408386,-8.6482594                  Glória
# 40.6405055,-8.6537539                  Glória
# -34.5492357,-58.5588195       Gral San Martin
# -34.5580546,-58.5625305       Gral San Martin
# 49.3269904,-123.0732801     Greater Vancouver
#                                   ...
# 36.7997069,10.1675245         Médina de Tunis
# 36.7969248,10.1766289         Médina de Tunis
# 28.7040592,77.1024902        North West Delhi
# 28.7705774,77.0794705        North West Delhi
# -26.4803234,-51.9908764                Palmas
# -10.249091,-48.3242858                 Palmas
# -27.5835097,-50.1582086              Palmeira
# -25.4245708,-50.0048569              Palmeira
# -21.0106742,-48.2176007          Pitangueiras
# -23.2286098,-51.5877624          Pitangueiras
# 42.1352878,24.7453972          Plovdiv Center
# 42.1354079,24.7452904          Plovdiv Center
# -9.930863,-36.5592982           São Sebastião
# -23.8063468,-45.4016534         São Sebastião
# -21.7414439,-48.6891129             Tabatinga
# -4.2314555,-69.9369359              Tabatinga
# 50.674522,-120.3272674        Thompson-Nicola
# 50.6761328,-120.2411463       Thompson-Nicola
# 41.9524718,3.1272343                  Torrent
# 39.4322368,-0.472373                  Torrent
# 49.018472,2.002694                 Val-d'Oise
# 49.008628,2.303938                 Val-d'Oise
# -22.2459149,-43.7068952               Valença
# -13.370017,-39.0720559                Valença
# -9.368056,-36.2434348                  Viçosa
# -20.7548659,-42.8785788                Viçosa
# 46.1535937,-64.7697901     Westmorland County
# 46.0878165,-64.7782313     Westmorland County
# 54.0009718,37.5203722            g. Shchekino
# 54.0068479,37.5153475            g. Shchekino
# dtype: object

# %%
def get_locality(coords):
    url = "https://maps.googleapis.com/maps/api/geocode/json?key=%s&latlng=%s" %(API_KEY, coords)
    r = requests.get(url)
    data = json_normalize(json.loads(r.text)["results"], "address_components")
    return data[data.types.map(lambda x: "locality" in x)]["short_name"].iloc[0]

# %%
get_locality(dupes.index[2])
# Out:
# 'Algueirão-Mem Martins'

# %%
localities = dict()

# %%
fails = list()
for coords in dupes.index.tolist():
    time.sleep(0.15)
    localities[coords] = get_locality(coords)

# %%
coords_and_areas.update(localities)
len(coords_and_areas)
# Out:
# 2033

# %%
missing = [i for i in ambiguous.coords if i not in coords_and_areas]
len(missing)
# Out:
# 73

# %%
missing_areas = dict()

# %%
for i in missing:
    time.sleep(0.15)
    missing_areas[i] = get_non_US_admin(i)

# %%
coords_and_areas.update(missing_areas)
len(coords_and_areas)
# Out:
# 2106

# %%
coords_and_areas = pd.Series(coords_and_areas, name = "coords")

# %%
disambiguated_cities = ambiguous.join(coords_and_areas, on="coords", how="left", rsuffix="_new").sort_values(by="city")
disambiguated_cities = disambiguated_cities.rename(columns = {"coords_new":"admin_area"})
disambiguated_cities.head()
# Out:
#                         coords      city        country  downloads admin_area
# 12572   45.4646985,-98.4864829  Aberdeen  United States          4         SD
# 13986  46.9753708,-123.8157218  Aberdeen  United States          1         WA
# 7668    39.5095556,-76.1641197  Aberdeen  United States         28         MD
# 6253     36.718147,-81.9621248  Abingdon  United States          2         VA
# 7632    39.4622357,-76.2772223  Abingdon  United States          4         MD

# %%
disambiguated_cities.groupby(["coords","country","city","admin_area"]).sum()
# Out:
#                                                                              downloads
# coords                  country        city          admin_area
# -1.4557549,-48.4901799  Brazil         Belém         Belém                       12724
# -10.249091,-48.3242858  Brazil         Palmas        Palmas                        739
# -10.6872332,-37.4329352 Brazil         Itabaiana     Itabaiana                     511
# -13.370017,-39.0720559  Brazil         Valença       Valença                        82
# -15.6580179,-47.7925346 Brazil         Brasília      Sobradinho                    263
# -15.7941874,-47.8825852 Brazil         Brasília      Brasília                    55878
# -15.813415,-48.1044183  Brazil         Brasília      Ceilândia                     527
# -15.8711088,-47.9709785 Brazil         Brasília      Núcleo Bandeirante              5
# 6.5243793,3.3792057     Nigeria        Lagos         Lagos                        8503
# 60.5372222,-150.7647222 United States  Sterling      AK                             22
# 60.7922222,-161.7558333 United States  Bethel        AK                              2
# 61.2180556,-149.9002778 United States  Anchorage     AK                            181
# 65.0120888,25.4650773   Finland        Oulu          Oulu                          530
# 65.1762807,25.3531972   Finland        Oulu          Haukipudas                    287
# 67.6107356,33.6724006   Russia         Kirovsk       g. Kirovsk                    665
# 67.9438833,34.5496594   Russia         Revda         Lovozerskiy r-n                 5
#
# [2106 rows x 1 columns]

# %% [markdown]
# **OK! All 2106 ambiguous cities are now accounted for.**

# %%
disambiguated_cities.to_csv("disambiguated_cities.csv")

# %% [markdown]
# **Now let's put it all together for mapping...**

# %%
disambiguated_cities = pd.read_csv("disambiguated_cities.csv", index_col = 0)
disambiguated_cities.head()
# Out:
#                         coords      city        country  downloads admin_area
# 12572   45.4646985,-98.4864829  Aberdeen  United States          4         SD
# 13986  46.9753708,-123.8157218  Aberdeen  United States          1         WA
# 7668    39.5095556,-76.1641197  Aberdeen  United States         28         MD
# 6253     36.718147,-81.9621248  Abingdon  United States          2         VA
# 7632    39.4622357,-76.2772223  Abingdon  United States          4         MD

# %%
by_coords = by_coords.join(disambiguated_cities.admin_area, how="left")
by_coords[by_coords.admin_area.notnull()]
# Out:
#                         coords           city         country  downloads  \
# 18      -1.4557549,-48.4901799          Belém          Brazil      12724
# 31      -10.249091,-48.3242858         Palmas          Brazil        739
# 38     -10.6872332,-37.4329352      Itabaiana          Brazil        511
# 109     -13.370017,-39.0720559        Valença          Brazil         82
# 149    -15.6580179,-47.7925346       Brasília          Brazil        263
# 152    -15.7941874,-47.8825852       Brasília          Brazil      55878
# 154     -15.813415,-48.1044183       Brasília          Brazil        527
# 156    -15.8711088,-47.9709785       Brasília          Brazil          5
# 157    -15.8729537,-48.0163953       Brasília          Brazil        544
# 265    -19.2464835,146.8020119    Castle Hill       Australia          2
# 295    -19.7884002,-43.9402344    Santa Luzia          Brazil        907
# 427    -20.7548659,-42.8785788         Viçosa          Brazil      10385
# 453    -21.0106742,-48.2176007   Pitangueiras          Brazil        238
# 493    -21.2518826,149.0564656       Homebush       Australia          5
# 550    -21.7414439,-48.6891129      Tabatinga          Brazil         45
# 594    -22.1631542,-42.4257912     Bom Jardim          Brazil          1
# 604    -22.2459149,-43.7068952        Valença          Brazil         50
# 781    -23.2286098,-51.5877624   Pitangueiras          Brazil         45
# 861    -23.8063468,-45.4016534  São Sebastião          Brazil         10
# 926    -25.4217847,-49.2740045       Curitiba          Brazil      32761
# 927    -25.4245708,-50.0048569       Palmeira          Brazil         85
# 934     -25.503107,-49.2368575       Curitiba          Brazil        131
# 996    -26.4803234,-51.9908764         Palmas          Brazil         17
# 1014   -26.7650048,-53.1745281      Maravilha          Brazil        111
# 1078   -27.3047492,153.0626884       Brighton       Australia         20
# 1102   -27.4368363,153.0310899        Windsor       Australia          9
# 1115   -27.4689176,153.0032389         Milton       Australia        229
# 1148    -27.5615863,153.068683      Macgregor       Australia         65
# 1154   -27.5835097,-50.1582086       Palmeira          Brazil          7
# 1174   -27.6602776,153.1175929       Kingston       Australia         11
# ...                        ...            ...             ...        ...
# 20348    53.2602149,-6.2047205         Dublin         Ireland         36
# 20361    53.2810955,-6.4345836         Dublin         Ireland          2
# 20393    53.3577525,-2.5629887       Appleton  United Kingdom         27
# 20396    53.3603142,-6.3150542         Dublin         Ireland      63047
# 20599     53.778422,20.4801193        Olsztyn          Poland        969
# 20618    53.8174245,-3.0352872      Blackpool  United Kingdom        629
# 20619    53.8175053,-3.0356748      Blackpool  United Kingdom          6
# 20631  53.8585381,-122.6873564  Prince George          Canada         17
# 20649  53.9170641,-122.7496693  Prince George          Canada         28
# 20671    54.0009718,37.5203722      Shchekino          Russia         87
# 20674    54.0068479,37.5153475      Shchekino          Russia         10
# 20756    54.3232927,10.1227652           Kiel         Germany       4195
# 20770     54.379444,10.1463889           Kiel         Germany        105
# 20784    54.4772015,53.4895394    Oktyabrskiy          Russia          6
# 21006    55.5962357,37.3451758     Moskovskiy          Russia         50
# 21230    56.1764464,47.2855244    Oktyabrskiy          Russia       1208
# 21252    56.2544955,93.5333646  Zheleznogorsk          Russia        159
# 21312    56.8188497,59.9036396          Revda          Russia        160
# 21341    57.1086076,65.4270782     Moskovskiy          Russia          2
# 21348    57.1920527,39.4136969         Rostov          Russia       2562
# 21569    59.8732962,30.9881874        Kirovsk          Russia        114
# 21596      6.4589849,3.6015207          Lagos         Nigeria         34
# 21598      6.5243793,3.3792057          Lagos         Nigeria       8503
# 21644  60.5372222,-150.7647222       Sterling   United States         22
# 21660  60.7922222,-161.7558333         Bethel   United States          2
# 21674  61.2180556,-149.9002778      Anchorage   United States        181
# 21749    65.0120888,25.4650773           Oulu         Finland        530
# 21751    65.1762807,25.3531972           Oulu         Finland        287
# 21771    67.6107356,33.6724006        Kirovsk          Russia        665
# 21774    67.9438833,34.5496594          Revda          Russia          5
#
#                    admin_area
# 18                      Belém
# 31                     Palmas
# 38                  Itabaiana
# 109                   Valença
# 149                Sobradinho
# 152                  Brasília
# 154                 Ceilândia
# 156        Núcleo Bandeirante
# 157                Taguatinga
# 265               Castle Hill
# 295              São Benedito
# 427                    Viçosa
# 453              Pitangueiras
# 493                  Homebush
# 550                 Tabatinga
# 594                Bom Jardim
# 604                   Valença
# 781              Pitangueiras
# 861             São Sebastião
# 926                    Matriz
# 927                  Palmeira
# 934                 Boqueirão
# 996                    Palmas
# 1014                Maravilha
# 1078                 Brighton
# 1102                  Windsor
# 1115                   Milton
# 1148                Macgregor
# 1154                 Palmeira
# 1174                 Kingston
# ...                       ...
# 20348  Dun Laoghaire-Rathdown
# 20361            South Dublin
# 20393                Appleton
# 20396             Dublin City
# 20599                 Olsztyn
# 20618               Blackpool
# 20619               Blackpool
# 20631    Fraser-Fort George D
# 20649      Fraser-Fort George
# 20671               Shchekino
# 20674               Shchekino
# 20756                      KI
# 20770                      KI
# 20784          g. Oktyabrskiy
# 21006           Leninskiy r-n
# 21230           g. Cheboksary
# 1102   -27.4368363,153.0310899        Windsor      Australia          9
# 1597    -33.6075314,150.819451        Windsor      Australia         24
# 11615   44.0553908,-91.6663523         Winona  United States         12
# 11542   43.9332109,-91.7300112         Winona  United States          9
# 6029    36.0898595,-80.3183851  Winston-Salem  United States          8
# 6033     36.0998596,-80.244216  Winston-Salem  United States        226
# 6021    36.0733867,-80.1793504  Winston-Salem  United States         74
# 7097    38.6581722,-77.2497049     Woodbridge  United States         68
# 7106       38.66671,-77.257288     Woodbridge  United States         15
# 9275    41.3645382,-74.1059775       Woodbury  United States          8
# 8730    40.8256545,-73.4676225       Woodbury  United States        106
# 10044      42.23903,-71.739098      Worcester  United States        139
# 10068   42.2625932,-71.8022934      Worcester  United States        958
# 7959    39.9617415,-76.7471062           York  United States         30
# 7960     39.9625984,-76.727745           York  United States          1
# 7979    39.9911093,-76.6699169           York  United States          5
#
#       admin_area
# 9033          OH
# 9029          OH
# 9017          OH
# 10392         NY
# 10460         NY
# 10465         NY
# 7156          VA
# 7191          VA
# 7215          VA
# 8474          PA
# 8457          PA
# 9869          IA
# 9878          IA
# 8076          IN
# 8109          IN
# 7344          MD
# 7339          MD
# 5837          NC
# 5807          NC
# 11762         WI
# 11712         WI
# 11708         WI
# 5769          NC
# 5735          NC
# 1727    Ashfield
# 1458    Ashfield
# 7135     Atalaia
# 7503     Atalaia
# 9679          IL
# 9674          IL
# ...          ...
# 7044          MO
# 7048          MO
# 9174          PA
# 9147          PA
# 6466          VA
# 6452          VA
# 6473          VA
# 5169          NC
# 5257          NC
# 5290          NC
# 5279          NC
# 5271          NC
# 5828          NC
# 5870          NC
# 1102     Windsor
# 1597     Windsor
# 11615         MN
# 11542         MN
# 6029          NC
# 6033          NC
# 6021          NC
# 7097          VA
# 7106          VA
# 9275          NY
# 8730          NY
# 10044         MA
# 10068         MA
# 7959          PA
# 7960          PA
# 7979          PA
#
# [629 rows x 5 columns]

# %% [markdown]
# **There are still 629 coords that have identical (country, city, admin_area).**

# %%
import requests, json
from pandas.io.json import json_normalize

A# You will need to register with Google Maps and get your own free API key
# https://developers.google.com/maps/documentation/javascript/get-api-key
API_KEY = "AjZaSyCaecKeKEr9NEv4zXaPzVVSds1FLTrtM4x"

def get_google_maps_data(coords):
    url = "https://maps.googleapis.com/maps/api/geocode/json?key=%s&latlng=%s" %(API_KEY, coords)
    r = requests.get(url)
    data = json_normalize(json.loads(r.text)["results"], "address_components")
    level_dict = dict([(i, None) for i in ("level_1", "level_2", "level_3", "level_4")])
    for level in level_dict:
        try:
            level_dict[level] = data[data.types.map(lambda x: "administrative_area_" + level in x)]["short_name"].iloc[0]
        except:
            pass
    return pd.Series(level_dict)

# %%
get_google_maps_data("39.9911093,-76.6699169")
# Out:
# level_1                         PA
# level_2                York County
# level_3    Springettsbury Township
# level_4                       None
# dtype: object

# %%
get_google_maps_data("39.9625984,-76.727745")
# Out:
# level_1             PA
# level_2    York County
# level_3           None
# level_4           None
# dtype: object

# %% [markdown]
# **And this makes it clear that it is not even possible to disambiguate some of these. Google Maps does not have specific administrative level information that we could use to distinguish them by name. Well, how geographically far are these ambiguous cities from their name duplicate coords?...**

# %%
from math import sin, cos, sqrt, atan2, radians

# radius of earth (km)
R = 6373.0

def geo_distance(coords1, coords2):
    lat1, lon1 = [radians(float(i)) for i in coords1.split(",")]
    lat2, lon2 = [radians(float(i)) for i in coords2.split(",")]
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c
    return distance

# %%
geo_distance("39.9911093,-76.6699169","39.9617415,-76.7471062")
# Out:
# 7.34562491329508

# %% [markdown]
# **Even 7 km is far enough to make the map wonky. So, executive decision: I'm just going to give the duplicates generic names such as "area 1 near York, PA, United States"... Expediency!**

# %%
def get_generic_area_name(map_name, n):
    return "area %s near %s" %(n, map_name)

get_generic_area_name("York, PA, United States", 2)
# Out:
# 'area 2 near York, PA, United States'

# %%
name_dict = dict()

def fix_stragglers(df):
    total = len(stragglers)
    x, y, z = df.iloc[0][["city","admin_area", "country"]]
    for n, c in enumerate(df.coords.tolist()):
        if z == "United States":
            name_dict[c] = get_generic_area_name("%s, %s, %s" %(x, y, z), n + 1)
        else:
            name_dict[c] = get_generic_area_name("%s, %s" %(x, z), n + 1)

# %%
x, y, z = ("United States", "Akron", "OH")
akron = stragglers[(stragglers.country == x) & (stragglers.city == y) & (stragglers.admin_area == z)]
akron
# Out:
#                       coords   city        country  downloads admin_area
# 9033  41.1010055,-81.6542827  Akron  United States          6         OH
# 9029    41.096295,-81.645289  Akron  United States          2         OH
# 9017  41.0814447,-81.5190053  Akron  United States       1090         OH

# %%
fix_stragglers(akron)
name_dict
# Out:
# {'41.0814447,-81.5190053': 'area 3 near Akron, OH, United States',
#  '41.096295,-81.645289': 'area 2 near Akron, OH, United States',
#  '41.1010055,-81.6542827': 'area 1 near Akron, OH, United States'}

# %%
for i in stragglers[["coords","city","admin_area", "country"]].values:
    x = i
print(x)
# Out:
# ['39.9911093,-76.6699169' 'York' 'PA' 'United States']

# %%
for i in stragglers[["city","admin_area", "country"]].values:
    x, y, z = i
    df = stragglers[(stragglers.city == x) & (stragglers.admin_area == y) & (stragglers.country == z)]
    fix_stragglers(df)

# %%
def make_name(coords):
    return name_dict[coords]

stragglers["map_name"] = stragglers.coords.apply(make_name)
stragglers
# Out:
#                         coords           city        country  downloads  \
# 9033    41.1010055,-81.6542827          Akron  United States          6
# 9029      41.096295,-81.645289          Akron  United States          2
# 9017    41.0814447,-81.5190053          Akron  United States       1090
# 10392   42.6525793,-73.7562317         Albany  United States        644
# 10460   42.7429277,-73.8694034         Albany  United States        672
# 10465   42.7482883,-73.8140654         Albany  United States         31
# 7156    38.7240679,-77.0904661     Alexandria  United States         15
# 7191    38.7668852,-77.0815654     Alexandria  United States         64
# 7215    38.8048355,-77.0469214     Alexandria  United States        110
# 8474    40.6084305,-75.4901833      Allentown  United States         53
# 8457    40.5879188,-75.4993831      Allentown  United States       1613
# 9869    42.0212746,-93.6153476           Ames  United States        152
# 9878    42.0307812,-93.6319131           Ames  United States        176
# 8076    40.0863481,-85.7051116       Anderson  United States          2
# 8474          PA      area 1 near Allentown, PA, United States
# 8457          PA      area 2 near Allentown, PA, United States
# 9869          IA           area 1 near Ames, IA, United States
# 9878          IA           area 2 near Ames, IA, United States
# 8076          IN       area 1 near Anderson, IN, United States
# 8109          IN       area 2 near Anderson, IN, United States
# 7344          MD      area 1 near Annapolis, MD, United States
# 7339          MD      area 2 near Annapolis, MD, United States
# 5837          NC           area 1 near Apex, NC, United States
# 5807          NC           area 2 near Apex, NC, United States
# 11762         WI       area 1 near Appleton, WI, United States
# 11712         WI       area 2 near Appleton, WI, United States
# 11708         WI       area 3 near Appleton, WI, United States
# 5769          NC      area 1 near Asheville, NC, United States
# 5735          NC      area 2 near Asheville, NC, United States
# 1727    Ashfield               area 1 near Ashfield, Australia
# 1458    Ashfield               area 2 near Ashfield, Australia
# 7135     Atalaia                 area 1 near Atalaia, Portugal
# 7503     Atalaia                 area 2 near Atalaia, Portugal
# 9679          IL         area 1 near Aurora, IL, United States
# 9674          IL         area 2 near Aurora, IL, United States
# ...          ...                                           ...
# 7044          MO       area 1 near Wildwood, MO, United States
# 7048          MO       area 2 near Wildwood, MO, United States
# 9174          PA   area 1 near Wilkes-Barre, PA, United States
# 9147          PA   area 2 near Wilkes-Barre, PA, United States
# 6466          VA   area 1 near Williamsburg, VA, United States
# 6452          VA   area 2 near Williamsburg, VA, United States
# 6473          VA   area 3 near Williamsburg, VA, United States
# 5169          NC     area 1 near Wilmington, NC, United States
# 5257          NC     area 2 near Wilmington, NC, United States
# 5290          NC     area 3 near Wilmington, NC, United States
# 5279          NC     area 4 near Wilmington, NC, United States
# 5271          NC     area 5 near Wilmington, NC, United States
# 5828          NC         area 1 near Wilson, NC, United States
# 5870          NC         area 2 near Wilson, NC, United States
# 1102     Windsor                area 1 near Windsor, Australia
# 1597     Windsor                area 2 near Windsor, Australia
# 11615         MN         area 1 near Winona, MN, United States
# 11542         MN         area 2 near Winona, MN, United States
# 6029          NC  area 1 near Winston-Salem, NC, United States
# 6033          NC  area 2 near Winston-Salem, NC, United States
# 6021          NC  area 3 near Winston-Salem, NC, United States
# 7097          VA     area 1 near Woodbridge, VA, United States
# 7106          VA     area 2 near Woodbridge, VA, United States
# 9275          NY       area 1 near Woodbury, NY, United States
# 8730          NY       area 2 near Woodbury, NY, United States
# 10044         MA      area 1 near Worcester, MA, United States
# 10068         MA      area 2 near Worcester, MA, United States
# 7959          PA           area 1 near York, PA, United States
# 7960          PA           area 2 near York, PA, United States
# 7979          PA           area 3 near York, PA, United States
#
# [629 rows x 6 columns]

# %%
by_coords.head()
# Out:
#                    coords                            city  country  downloads  \
# 0   -0.0917016,34.7679568                          Kisumu    Kenya          5
# 1  -0.1806532,-78.4678382                           Quito  Ecuador      83065
# 2  -0.2389045,-79.1774268  Santo Domingo de los Colorados  Ecuador        258
# 3    -0.3030988,36.080026                          Nakuru    Kenya         13
# 4  -0.3301412,-78.4499915                       Sangolquí  Ecuador          2
#
#   admin_area
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
def get_map_name(admin_area, city, country):
    if type(admin_area) != str or admin_area == city:
        return "%s, %s" %(city, country)
    elif country == "United States":
        return "%s, %s, %s" %(city, admin_area, country)
    else:
        return "%s, %s, %s" %(admin_area, city, country)

by_coords["map_name"] = by_coords.apply(lambda x: get_map_name(x["admin_area"], x["city"], x["country"]), axis=1)
by_coords.head()
# Out:
#                    coords                            city  country  downloads  \
# 0   -0.0917016,34.7679568                          Kisumu    Kenya          5
# 1  -0.1806532,-78.4678382                           Quito  Ecuador      83065
# 2  -0.2389045,-79.1774268  Santo Domingo de los Colorados  Ecuador        258
# 3    -0.3030988,36.080026                          Nakuru    Kenya         13
# 4  -0.3301412,-78.4499915                       Sangolquí  Ecuador          2
#
#   admin_area                                 map_name
# 0        NaN                            Kisumu, Kenya
# 1        NaN                           Quito, Ecuador
# 2        NaN  Santo Domingo de los Colorados, Ecuador
# 3        NaN                            Nakuru, Kenya
# 4        NaN                       Sangolquí, Ecuador

# %%
len(by_coords)
# Out:
# 21907

# %%
by_coords[by_coords.admin_area.notnull()]
# Out:
#                         coords           city         country  downloads  \
# 18      -1.4557549,-48.4901799          Belém          Brazil      12724
# 31      -10.249091,-48.3242858         Palmas          Brazil        739
# 38     -10.6872332,-37.4329352      Itabaiana          Brazil        511
# 109     -13.370017,-39.0720559        Valença          Brazil         82
# 149    -15.6580179,-47.7925346       Brasília          Brazil        263
# 152    -15.7941874,-47.8825852       Brasília          Brazil      55878
# 154     -15.813415,-48.1044183       Brasília          Brazil        527
# 156    -15.8711088,-47.9709785       Brasília          Brazil          5
# 157    -15.8729537,-48.0163953       Brasília          Brazil        544
# 265    -19.2464835,146.8020119    Castle Hill       Australia          2
# 295    -19.7884002,-43.9402344    Santa Luzia          Brazil        907
# 427    -20.7548659,-42.8785788         Viçosa          Brazil      10385
# 453    -21.0106742,-48.2176007   Pitangueiras          Brazil        238
# 493    -21.2518826,149.0564656       Homebush       Australia          5
# 550    -21.7414439,-48.6891129      Tabatinga          Brazil         45
# 594    -22.1631542,-42.4257912     Bom Jardim          Brazil          1
# 604    -22.2459149,-43.7068952        Valença          Brazil         50
# 781    -23.2286098,-51.5877624   Pitangueiras          Brazil         45
# 861    -23.8063468,-45.4016534  São Sebastião          Brazil         10
# 926    -25.4217847,-49.2740045       Curitiba          Brazil      32761
# 927    -25.4245708,-50.0048569       Palmeira          Brazil         85
# 934     -25.503107,-49.2368575       Curitiba          Brazil        131
# 996    -26.4803234,-51.9908764         Palmas          Brazil         17
# 1014   -26.7650048,-53.1745281      Maravilha          Brazil        111
# 1078   -27.3047492,153.0626884       Brighton       Australia         20
# 1102   -27.4368363,153.0310899        Windsor       Australia          9
# 1115   -27.4689176,153.0032389         Milton       Australia        229
# 1148    -27.5615863,153.068683      Macgregor       Australia         65
# 1154   -27.5835097,-50.1582086       Palmeira          Brazil          7
# 1174   -27.6602776,153.1175929       Kingston       Australia         11
# ...                        ...            ...             ...        ...
# 20348    53.2602149,-6.2047205         Dublin         Ireland         36
# 20361    53.2810955,-6.4345836         Dublin         Ireland          2
# 20393    53.3577525,-2.5629887       Appleton  United Kingdom         27
# 11762         WI       Appleton, WI, United States
# 11712         WI       Appleton, WI, United States
# 11708         WI       Appleton, WI, United States
# 5769          NC      Asheville, NC, United States
# 5735          NC      Asheville, NC, United States
# 1727    Ashfield               Ashfield, Australia
# 1458    Ashfield               Ashfield, Australia
# 7135     Atalaia                 Atalaia, Portugal
# 7503     Atalaia                 Atalaia, Portugal
# 9679          IL         Aurora, IL, United States
# 9674          IL         Aurora, IL, United States
# ...          ...                               ...
# 7044          MO       Wildwood, MO, United States
# 7048          MO       Wildwood, MO, United States
# 9174          PA   Wilkes-Barre, PA, United States
# 9147          PA   Wilkes-Barre, PA, United States
# 6466          VA   Williamsburg, VA, United States
# 6452          VA   Williamsburg, VA, United States
# 6473          VA   Williamsburg, VA, United States
# 5169          NC     Wilmington, NC, United States
# 5257          NC     Wilmington, NC, United States
# 5290          NC     Wilmington, NC, United States
# 5279          NC     Wilmington, NC, United States
# 5271          NC     Wilmington, NC, United States
# 5828          NC         Wilson, NC, United States
# 5870          NC         Wilson, NC, United States
# 1102     Windsor                Windsor, Australia
# 1597     Windsor                Windsor, Australia
# 11615         MN         Winona, MN, United States
# 11542         MN         Winona, MN, United States
# 6029          NC  Winston-Salem, NC, United States
# 6033          NC  Winston-Salem, NC, United States
# 6021          NC  Winston-Salem, NC, United States
# 7097          VA     Woodbridge, VA, United States
# 7106          VA     Woodbridge, VA, United States
# 9275          NY       Woodbury, NY, United States
# 8730          NY       Woodbury, NY, United States
# 10044         MA      Worcester, MA, United States
# 10068         MA      Worcester, MA, United States
# 7959          PA           York, PA, United States
# 7960          PA           York, PA, United States
# 7979          PA           York, PA, United States
#
# [629 rows x 6 columns]

# %%
name_dict = dict()

def fix_final_stragglers(df):
    total = len(stragglers)
    x, y, z = df.iloc[0][["city","admin_area", "country"]]
    for n, c in enumerate(df.coords.tolist()):
        if z == "United States":
            name_dict[c] = get_generic_area_name("%s, %s, %s" %(x, y, z), n + 1)
        else:
            name_dict[c] = get_generic_area_name("%s, %s" %(x, z), n + 1)

# %%
for i in still_straggling[["city","admin_area", "country"]].values:
    x, y, z = i
    df = still_straggling[(still_straggling.city == x) & (still_straggling.admin_area == y) & (still_straggling.country == z)]
    fix_stragglers(df)

# %%
name_dict
# Out:
# {'-1.4557549,-48.4901799': 'area 2 near Belém, Brazil',
#  '-10.249091,-48.3242858': 'area 1 near Palmas, Brazil',
#  '-10.6872332,-37.4329352': 'area 2 near Itabaiana, Brazil',
#  '-13.370017,-39.0720559': 'area 1 near Valença, Brazil',
#  '-19.2464835,146.8020119': 'area 2 near Castle Hill, Australia',
#  '-20.7548659,-42.8785788': 'area 2 near Viçosa, Brazil',
#  '-21.0106742,-48.2176007': 'area 1 near Pitangueiras, Brazil',
#  '-21.2518826,149.0564656': 'area 2 near Homebush, Australia',
#  '-21.7414439,-48.6891129': 'area 2 near Tabatinga, Brazil',
#  '-22.1631542,-42.4257912': 'area 1 near Bom Jardim, Brazil',
#  '-22.2459149,-43.7068952': 'area 2 near Valença, Brazil',
#  '-23.2286098,-51.5877624': 'area 2 near Pitangueiras, Brazil',
#  '-23.8063468,-45.4016534': 'area 1 near São Sebastião, Brazil',
#  '-25.4245708,-50.0048569': 'area 1 near Palmeira, Brazil',
#  '-26.4803234,-51.9908764': 'area 2 near Palmas, Brazil',
#  '-26.7650048,-53.1745281': 'area 1 near Maravilha, Brazil',
#  '-27.3047492,153.0626884': 'area 3 near Brighton, Australia',
#  '-27.4368363,153.0310899': 'area 1 near Windsor, Australia',
#  '-27.4689176,153.0032389': 'area 1 near Milton, Australia',
#  '-27.5615863,153.068683': 'area 2 near Macgregor, Australia',
#  '-27.5835097,-50.1582086': 'area 2 near Palmeira, Brazil',
#  '-27.6602776,153.1175929': 'area 2 near Kingston, Australia',
#  '-29.9477228,-51.1021166': 'area 1 near Cachoeirinha, Brazil',
#  '-30.7893901,-60.5935165': 'area 2 near San Justo, Argentina',
#  '-31.91326,115.9361358': 'area 2 near Ashfield, Australia',
#  '-31.9943669,115.8597483': 'area 2 near Como, Australia',
#  '-32.0000546,115.9520557': 'area 2 near Queens Park, Australia',
#  '-32.0671578,115.7720727': 'area 1 near Beaconsfield, Australia',
#  '-33.6075314,150.819451': 'area 2 near Windsor, Australia',
#  '-33.7330058,151.0026388': 'area 1 near Castle Hill, Australia',
#  '-33.7727711,151.0813486': 'area 2 near Epping, Australia',
#  '-33.8672238,151.084709': 'area 1 near Homebush, Australia',
#  '-33.8775547,151.1037054': 'area 1 near Burwood, Australia',
#  '-33.8830466,151.1144171': 'area 1 near Croydon, Australia',
#  '-33.8885698,151.1241979': 'area 1 near Ashfield, Australia',
#  '-33.9002853,151.2528425': 'area 1 near Queens Park, Australia',
#  '-33.9100068,151.2229804': 'area 2 near Kensington, Australia',
#  '-34.0041765,151.0689861': 'area 1 near Como, Australia',
#  '-34.5492357,-58.5588195': 'area 2 near Villa Ballester, Argentina',
#  '-34.5580546,-58.5625305': 'area 1 near Villa Ballester, Argentina',
#  '-34.6658223,-58.6985675': 'area 1 near Merlo, Argentina',
#  '-34.6685004,-58.7282483': 'area 2 near Merlo, Argentina',
#  '-34.6874084,-58.5632629': 'area 1 near San Justo, Argentina',
#  '-34.8983337,138.5946408': 'area 2 near Fitzroy, Australia',
#  '-35.0208107,138.5231007': 'area 1 near Brighton, Australia',
#  '-35.2102303,149.0117573': 'area 1 near Macgregor, Australia',
#  '-35.3157823,150.4353354': 'area 2 near Milton, Australia',
#  '-37.6459318,145.0403335': 'area 1 near Epping, Australia',
#  '-37.79443,144.930267': 'area 1 near Kensington, Australia',
#  '-37.796322,145.281036': 'area 2 near Croydon, Australia',
#  '-37.7987007,144.9786869': 'area 1 near Fitzroy, Australia',
#  '-37.814107,144.96328': 'area 2 near Melbourne, Australia',
#  '-37.8142155,144.9632307': 'area 1 near Melbourne, Australia',
#  '-37.8501405,145.1190313': 'area 2 near Burwood, Australia',
#  '-37.9056598,145.0043117': 'area 2 near Brighton, Australia',
#  '-38.04554,145.3672877': 'area 2 near Beaconsfield, Australia',
#  '-4.2314555,-69.9369359': 'area 1 near Tabatinga, Brazil',
#  '-42.9756751,147.3094943': 'area 1 near Kingston, Australia',
#  '-6.6956001,-35.5355783': 'area 1 near Belém, Brazil',
#  '-7.3296633,-35.3330235': 'area 1 near Itabaiana, Brazil',
#  '-7.7973604,-35.5787115': 'area 2 near Bom Jardim, Brazil',
#  '-8.4892195,-36.2374768': 'area 2 near Cachoeirinha, Brazil',
#  '-9.230872,-37.3527565': 'area 2 near Maravilha, Brazil',
#  '-9.368056,-36.2434348': 'area 1 near Viçosa, Brazil',
#  '-9.930863,-36.5592982': 'area 2 near São Sebastião, Brazil',
#  '13.0587471,80.254435': 'area 2 near Chennai, India',
#  '13.0826802,80.2707184': 'area 1 near Chennai, India',
#  '14.5988523,121.0146475': 'area 3 near Manila, Philippines',
#  '14.5995124,120.9842195': 'area 2 near Manila, Philippines',
#  '14.6154969,120.9846789': 'area 1 near Manila, Philippines',
#  '14.6760413,121.0437003': 'area 2 near Quezon City, Philippines',
#  '14.7090471,121.0235363': 'area 1 near Quezon City, Philippines',
#  '19.0176169,72.8561288': 'area 2 near Mumbai, India',
#  '19.0759837,72.8776559': 'area 1 near Mumbai, India',
#  '19.1538231,72.8751786': 'area 3 near Mumbai, India',
#  '19.4326077,-99.133208': 'area 2 near Ciudad de México, Mexico',
#  '19.4873329,-99.1236134': 'area 1 near Ciudad de México, Mexico',
#  '19.5324951,-99.1407725': 'area 3 near Ciudad de México, Mexico',
#  '22.5402602,88.3821989': 'area 2 near Kolkata, India',
#  '22.572646,88.363895': 'area 1 near Kolkata, India',
#  '26.074508,119.296494': 'area 2 near Fuzhou Shi, China',
#  '27.949217,116.358182': 'area 1 near Fuzhou Shi, China',
#  '28.65638,121.42076': 'area 2 near Taizhou Shi, China',
#  '28.7040592,77.1024902': 'area 1 near New Delhi, India',
#  '28.7705774,77.0794705': 'area 2 near New Delhi, India',
#  '30.0038051,-91.8223025': 'area 1 near New Iberia, LA, United States',
#  '30.019769,-91.7667055': 'area 2 near New Iberia, LA, United States',
#  '30.218053,-93.19305': 'area 2 near Lake Charles, LA, United States',
#  '30.2288602,-93.2332244': 'area 1 near Lake Charles, LA, United States',
#  '30.3964774,-90.0903135': 'area 2 near Mandeville, LA, United States',
#  '30.3969294,-91.0145313': 'area 4 near Baton Rouge, LA, United States',
#  '30.3988391,-90.0882934': 'area 1 near Mandeville, LA, United States',
#  '30.4417882,-91.1773301': 'area 9 near Baton Rouge, LA, United States',
#  '30.4483714,-91.1495866': 'area 7 near Baton Rouge, LA, United States',
#  '30.4516539,-91.1847534': 'area 1 near Baton Rouge, LA, United States',
#  '30.4517129,-91.1787612': 'area 5 near Baton Rouge, LA, United States',
#  '30.4520905,-91.1859574': 'area 8 near Baton Rouge, LA, United States',
#  '30.4582829,-91.1403196': 'area 6 near Baton Rouge, LA, United States',
#  '30.4597328,-91.1879944': 'area 3 near Baton Rouge, LA, United States',
#  '30.4630586,-90.1047114': 'area 1 near Covington, LA, United States',
#  '30.4915259,-90.0983352': 'area 2 near Covington, LA, United States',
#  '36.216795,-81.6745517': 'area 2 near Boone, NC, United States',
#  '36.216949,-81.7147646': 'area 1 near Boone, NC, United States',
#  '36.7969248,10.1766289': 'area 1 near Tunis, Tunisia',
#  '36.7997069,10.1675245': 'area 2 near Tunis, Tunisia',
#  '37.0193161,-94.5005808': 'area 2 near Joplin, MO, United States',
#  '37.1065464,-94.4593791': 'area 1 near Joplin, MO, United States',
#  '37.1298517,-80.4089389': 'area 2 near Christiansburg, VA, United States',
#  '37.1735623,-80.4199469': 'area 1 near Christiansburg, VA, United States',
#  '37.183887,-77.5075': 'area 1 near Petersburg, VA, United States',
#  '37.2279279,-77.4019267': 'area 2 near Petersburg, VA, United States',
#  '37.2497339,-76.7343662': 'area 2 near Williamsburg, VA, United States',
#  '37.2529145,-80.0064271': 'area 3 near Roanoke, VA, United States',
#  '37.2545699,-79.9114421': 'area 1 near Roanoke, VA, United States',
#  '37.2707022,-76.7074571': 'area 1 near Williamsburg, VA, United States',
#  '37.2709704,-79.9414266': 'area 2 near Roanoke, VA, United States',
#  '37.2792932,-76.6136785': 'area 3 near Williamsburg, VA, United States',
#  '37.3875656,-77.6380658': 'area 1 near Midlothian, VA, United States',
#  '37.3968239,-79.118878': 'area 2 near Lynchburg, VA, United States',
#  '37.4137536,-79.1422464': 'area 1 near Lynchburg, VA, United States',
#  '37.4929961,-77.5293428': 'area 7 near Richmond, VA, United States',
#  '37.5011782,-77.5074774': 'area 6 near Richmond, VA, United States',
#  '37.5059814,-77.6491578': 'area 2 near Midlothian, VA, United States',
#  '37.5407246,-77.4360481': 'area 5 near Richmond, VA, United States',
#  '37.5496956,-77.4034927': 'area 3 near Richmond, VA, United States',
#  '37.5554169,-77.347063': 'area 2 near Richmond, VA, United States',
#  '37.5775563,-77.5263698': 'area 4 near Richmond, VA, United States',
#  '37.5872921,-77.3111461': 'area 1 near Mechanicsville, VA, United States',
#  '37.6087561,-77.3733139': 'area 2 near Mechanicsville, VA, United States',
#  '37.628661,-77.509646': 'area 1 near Richmond, VA, United States',
#  '37.6871761,-97.330053': 'area 2 near Wichita, KS, United States',
#  '37.71933,-97.4167793': 'area 1 near Wichita, KS, United States',
#  '37.9448922,-78.5355322': 'area 3 near Charlottesville, VA, United States',
#  '37.9692247,-87.564304': 'area 2 near Evansville, IN, United States',
#  '37.9727533,-87.4802068': 'area 3 near Evansville, IN, United States',
#  '37.978934,-87.605685': 'area 4 near Evansville, IN, United States',
#  '38.0090953,-78.7028703': 'area 2 near Charlottesville, VA, United States',
#  '38.0356981,-78.5035945': 'area 1 near Charlottesville, VA, United States',
#  '38.048279,-87.5494745': 'area 5 near Evansville, IN, United States',
#  '38.0627171,-97.9543171': 'area 2 near Hutchinson, KS, United States',
#  '38.0919076,-97.9271885': 'area 1 near Hutchinson, KS, United States',
#  '38.1121242,-87.5200244': 'area 1 near Evansville, IN, United States',
#  '38.2735971,-77.590999': 'area 2 near Fredericksburg, VA, United States',
#  '38.3031837,-77.4605399': 'area 3 near Fredericksburg, VA, United States',
#  '38.3888686,-82.4679628': 'area 2 near Huntington, WV, United States',
#  '38.4042793,-82.3737935': 'area 1 near Huntington, WV, United States',
#  '38.4220687,-77.4083086': 'area 2 near Stafford, VA, United States',
#  '38.4223427,-77.4089385': 'area 1 near Stafford, VA, United States',
#  '38.4264433,-82.4181811': 'area 3 near Huntington, WV, United States',
#  '38.427495,-90.021033': 'area 1 near Belleville, IL, United States',
#  '38.4495688,-78.8689155': 'area 2 near Harrisonburg, VA, United States',
#  '38.450541,-77.5872212': 'area 1 near Fredericksburg, VA, United States',
#  '38.4530404,-90.3089777': 'area 2 near St. Louis, MO, United States',
#  '38.4871028,-78.8703183': 'area 1 near Harrisonburg, VA, United States',
#  '38.4947071,-92.1005946': 'area 2 near Jefferson City, MO, United States',
#  '38.4948766,-90.3842527': 'area 3 near St. Louis, MO, United States',
#  '38.5320641,-89.8386224': 'area 2 near Belleville, IL, United States',
#  '38.5527373,-90.3607137': 'area 1 near St. Louis, MO, United States',
#  '38.5767017,-92.1735164': 'area 1 near Jefferson City, MO, United States',
#  '38.5778526,-90.6298922': 'area 1 near Wildwood, MO, United States',
#  '38.582831,-90.6629047': 'area 2 near Wildwood, MO, United States',
#  '38.5870642,-76.8666369': 'area 2 near Waldorf, MD, United States',
#  '38.6087053,-90.486544': 'area 1 near Ballwin, MO, United States',
#  '38.6202992,-90.5352356': 'area 2 near Ballwin, MO, United States',
#  '38.6265124,-76.9105483': 'area 1 near Waldorf, MD, United States',
#  '38.6270025,-90.1994042': 'area 7 near St. Louis, MO, United States',
#  '38.6314692,-90.3560076': 'area 4 near St. Louis, MO, United States',
#  '38.6581722,-77.2497049': 'area 1 near Woodbridge, VA, United States',
#  '38.66671,-77.257288': 'area 2 near Woodbridge, VA, United States',
#  '38.7012207,-8.927294': 'area 1 near Atalaia, Portugal',
#  '38.7043396,-90.4974359': 'area 6 near St. Louis, MO, United States',
#  '38.7049868,-90.3089777': 'area 5 near St. Louis, MO, United States',
#  '38.7134516,-77.7952712': 'area 2 near Warrenton, VA, United States',
#  '38.7145259,-77.8008563': 'area 1 near Warrenton, VA, United States',
#  '38.7240679,-77.0904661': 'area 1 near Alexandria, VA, United States',
#  '38.7509488,-77.4752667': 'area 2 near Manassas, VA, United States',
#  '38.7668852,-77.0815654': 'area 2 near Alexandria, VA, United States',
#  '38.7717822,-77.5542966': 'area 1 near Manassas, VA, United States',
#  '38.7942443,-90.3261675': 'area 2 near Florissant, MO, United States',
#  '38.8048355,-77.0469214': 'area 3 near Alexandria, VA, United States',
#  '38.82091,-90.229455': 'area 1 near Florissant, MO, United States',
#  '38.8225053,-77.3578924': 'area 1 near Fairfax, VA, United States',
#  '38.828842,-76.833916': 'area 1 near Upper Marlboro, MD, United States',
#  '38.8497119,-77.2038084': 'area 3 near Falls Church, VA, United States',
#  '38.8617451,-77.3828502': 'area 2 near Fairfax, VA, United States',
#  '38.8649558,-77.3821282': 'area 3 near Fairfax, VA, United States',
#  '38.8725368,-92.3260183': 'area 3 near Columbia, MO, United States',
#  '38.8813958,-94.8191285': 'area 2 near Olathe, KS, United States',
#  '38.882334,-77.1710914': 'area 1 near Falls Church, VA, United States',
#  '38.8909449,-77.184425': 'area 2 near Falls Church, VA, United States',
#  '38.8942786,-77.4310992': 'area 2 near Chantilly, VA, United States',
#  '38.900691,-94.470642': 'area 1 near Kansas City, MO, United States',
#  '38.9045588,-76.6813486': 'area 2 near Upper Marlboro, MD, United States',
#  '38.9088253,-94.8313257': 'area 1 near Olathe, KS, United States',
#  '38.9108408,-94.3821724': "area 1 near Lee's Summit, MO, United States",
#  '38.9218718,-76.8958756': 'area 2 near Hyattsville, MD, United States',
#  '38.9293344,-77.5191214': 'area 1 near Chantilly, VA, United States',
#  '38.9306681,-95.2893433': 'area 1 near Lawrence, KS, United States',
#  '38.9399017,-77.3844227': 'area 2 near Herndon, VA, United States',
#  '38.9527006,-76.947022': 'area 1 near Hyattsville, MD, United States',
#  '38.9559442,-76.9455301': 'area 3 near Hyattsville, MD, United States',
#  '38.9600298,-92.2364212': 'area 2 near Columbia, MO, United States',
#  '38.9695545,-77.3860976': 'area 1 near Herndon, VA, United States',
#  '38.9716689,-95.2352501': 'area 2 near Lawrence, KS, United States',
#  '38.9784453,-76.4921829': 'area 2 near Annapolis, MD, United States',
#  '38.9795104,-95.2222788': 'area 3 near Lawrence, KS, United States',
#  '38.9814548,-76.5660597': 'area 1 near Annapolis, MD, United States',
#  '38.984652,-77.0947092': 'area 2 near Bethesda, MD, United States',
#  '38.9906657,-77.026088': 'area 1 near Silver Spring, MD, United States',
#  '38.9920626,-77.0917667': 'area 1 near Bethesda, MD, United States',
#  '39.0026518,-77.3956004': 'area 1 near Sterling, VA, United States',
#  '39.002939,-94.343159': "area 2 near Lee's Summit, MO, United States",
#  '39.0049347,-92.3043673': 'area 1 near Columbia, MO, United States',
#  '39.0066993,-77.4291298': 'area 2 near Sterling, VA, United States',
#  '39.0209659,-77.0118921': 'area 2 near Silver Spring, MD, United States',
#  '39.0558235,-95.6890185': 'area 1 near Topeka, KS, United States',
#  '39.0716767,-86.5453664': 'area 4 near Bloomington, IN, United States',
#  '39.0718625,-76.8320502': 'area 2 near Laurel, MD, United States',
#  '39.0740189,-84.3902595': 'area 6 near Cincinnati, OH, United States',
#  '39.0832116,-95.704727': 'area 2 near Topeka, KS, United States',
#  '39.085345,-94.5830789': 'area 4 near Kansas City, MO, United States',
#  '39.086939,-77.486076': 'area 2 near Leesburg, VA, United States',
#  '39.0992752,-76.8483061': 'area 1 near Laurel, MD, United States',
#  '39.1031182,-84.5120196': 'area 1 near Cincinnati, OH, United States',
#  '39.1156615,-77.5636015': 'area 1 near Leesburg, VA, United States',
#  '39.1288874,-86.4421011': 'area 2 near Bloomington, IN, United States',
#  '39.1347484,-84.5362787': 'area 4 near Cincinnati, OH, United States',
#  '39.1434406,-77.2013705': 'area 2 near Gaithersburg, MD, United States',
#  '39.165325,-86.5263857': 'area 1 near Bloomington, IN, United States',
#  '39.1655403,-86.4990777': 'area 3 near Bloomington, IN, United States',
#  '39.1672417,-77.161383': 'area 1 near Gaithersburg, MD, United States',
#  '39.8916369,-85.9917437': 'area 6 near Indianapolis, IN, United States',
#  '39.8957914,-86.1141045': 'area 7 near Indianapolis, IN, United States',
#  '39.906515,-86.203548': 'area 8 near Indianapolis, IN, United States',
#  '39.9142542,-88.8838834': 'area 2 near Decatur, IL, United States',
#  '39.9242266,-83.8088171': 'area 2 near Springfield, OH, United States',
#  '39.926944,-83.804167': 'area 1 near Springfield, OH, United States',
#  '39.9375911,-77.6611022': 'area 1 near Chambersburg, PA, United States',
#  '39.9507205,-77.6453326': 'area 2 near Chambersburg, PA, United States',
#  '39.953878,-83.0001295': 'area 1 near Columbus, OH, United States',
#  '39.9611755,-82.9987942': 'area 2 near Columbus, OH, United States',
#  '39.9617415,-76.7471062': 'area 1 near York, PA, United States',
#  '39.9625984,-76.727745': 'area 2 near York, PA, United States',
#  '39.9645049,-86.0223611': 'area 1 near Fishers, IN, United States',
#  '39.9694469,-83.0093251': 'area 3 near Columbus, OH, United States',
#  '39.9708567,-85.9100089': 'area 2 near Fishers, IN, United States',
#  '39.9758085,-82.9695735': 'area 4 near Columbus, OH, United States',
#  '39.9911093,-76.6699169': 'area 3 near York, PA, United States',
#  '40.0092831,-75.7020489': 'area 2 near Downingtown, PA, United States',
#  '40.0187036,-76.2777789': 'area 1 near Lancaster, PA, United States',
#  '40.0263085,-76.2961446': 'area 4 near Lancaster, PA, United States',
#  '40.0378755,-76.3055144': 'area 3 near Lancaster, PA, United States',
#  '40.0406721,-75.7221428': 'area 1 near Downingtown, PA, United States',
#  '40.0825041,-76.308347': 'area 2 near Lancaster, PA, United States',
#  '40.0863481,-85.7051116': 'area 1 near Anderson, IN, United States',
#  '40.1261743,-82.9290696': 'area 1 near Westerville, OH, United States',
#  '40.1317709,-85.6820766': 'area 2 near Anderson, IN, United States',
#  '40.1426554,-82.9877866': 'area 5 near Columbus, OH, United States',
#  '40.1604368,-82.9346941': 'area 2 near Westerville, OH, United States',
#  '40.1639366,-75.7188871': 'area 2 near Pottstown, PA, United States',
#  '40.187778,-77.174164': 'area 1 near Carlisle, PA, United States',
#  '40.1956406,-76.9754251': 'area 1 near Mechanicsburg, PA, United States',
#  '40.1963133,-85.3756249': 'area 1 near Muncie, IN, United States',
#  '40.2010241,-77.2002745': 'area 2 near Carlisle, PA, United States',
#  '40.2115109,-74.6796651': 'area 2 near Hamilton Township, NJ, United States',
#  '40.242348,-85.395859': 'area 2 near Muncie, IN, United States',
#  '40.2484518,-77.0218209': 'area 2 near Mechanicsburg, PA, United States',
#  '40.2645371,-75.8040852': 'area 2 near Birdsboro, PA, United States',
#  '40.2654025,-75.6424065': 'area 1 near Pottstown, PA, United States',
#  '40.2731911,-76.8867008': 'area 2 near Harrisburg, PA, United States',
#  '40.2873059,-76.0032849': 'area 1 near Reading, PA, United States',
#  '40.302411,-75.7927232': 'area 1 near Birdsboro, PA, United States',
#  '40.3042839,-75.1492516': 'area 1 near Doylestown, PA, United States',
#  '40.304688,-76.8181939': 'area 1 near Harrisburg, PA, United States',
#  '40.3101063,-75.1298939': 'area 2 near Doylestown, PA, United States',
#  '40.316111,-78.833889': 'area 2 near Johnstown, PA, United States',
#  '40.3267407,-78.9219698': 'area 1 near Johnstown, PA, United States',
#  '40.328216,-86.8822445': 'area 1 near Lafayette, IN, United States',
#  '40.3356483,-75.9268747': 'area 2 near Reading, PA, United States',
#  '40.336419,-74.4330474': 'area 1 near Monroe Township, NJ, United States',
#  '40.3425199,-78.93685': 'area 3 near Johnstown, PA, United States',
#  '40.3495363,-76.4170648': 'area 2 near Lebanon, PA, United States',
#  '40.3608664,-80.0690333': 'area 2 near Pittsburgh, PA, United States',
#  '40.3886573,-86.7041416': 'area 3 near Lafayette, IN, United States',
#  '40.4090087,-76.4559377': 'area 1 near Lebanon, PA, United States',
#  '40.4394268,-80.0808548': 'area 5 near Pittsburgh, PA, United States',
#  '40.4406248,-79.9958864': 'area 3 near Pittsburgh, PA, United States',
#  '40.4493696,-86.8421125': 'area 2 near Lafayette, IN, United States',
#  '40.4573167,-79.9129713': 'area 4 near Pittsburgh, PA, United States',
#  '40.479692,-86.19925': 'area 2 near Kokomo, IN, United States',
#  '40.4842027,-88.9936873': 'area 1 near Bloomington, IL, United States',
#  '40.487806,-86.139586': 'area 1 near Kokomo, IN, United States',
#  '40.4967236,-88.9232366': 'area 2 near Bloomington, IL, United States',
#  '40.5052711,-80.049148': 'area 1 near Pittsburgh, PA, United States',
#  '40.5195337,-80.0250612': 'area 6 near Pittsburgh, PA, United States',
#  '40.5879188,-75.4993831': 'area 2 near Allentown, PA, United States',
#  '40.6084305,-75.4901833': 'area 1 near Allentown, PA, United States',
#  '40.6214551,-79.1525349': 'area 2 near Indiana, PA, United States',
#  '40.6259316,-75.3704579': 'area 3 near Bethlehem, PA, United States',
#  '40.6333622,-79.1003759': 'area 1 near Indiana, PA, United States',
#  '40.6405055,-8.6537539': 'area 1 near Aveiro, Portugal',
#  '40.6408386,-8.6482594': 'area 2 near Aveiro, Portugal',
#  '40.6632966,-75.2764838': 'area 1 near Easton, PA, United States',
#  '40.6684725,-75.3973234': 'area 2 near Bethlehem, PA, United States',
#  '40.6750981,-75.3246237': 'area 1 near Bethlehem, PA, United States',
#  '40.704832,-84.026791': 'area 3 near Lima, OH, United States',
#  '40.7421464,-75.1964133': 'area 2 near Easton, PA, United States',
#  '40.742551,-84.1052256': 'area 2 near Lima, OH, United States',
#  '40.75839,-82.5154471': 'area 2 near Mansfield, OH, United States',
#  '40.7588064,-81.3378787': 'area 5 near Canton, OH, United States',
#  '40.7632259,-84.0491207': 'area 1 near Lima, OH, United States',
#  '40.7674507,-82.5294065': 'area 1 near Mansfield, OH, United States',
#  '40.7695876,-74.8039205': 'area 2 near Washington Township, NJ, United States',
#  '40.785834,-77.8504449': 'area 1 near State College, PA, United States',
#  '40.7933949,-77.8600012': 'area 2 near State College, PA, United States',
#  '40.7989473,-81.378447': 'area 1 near Canton, OH, United States',
#  '40.804673,-81.453977': 'area 4 near Canton, OH, United States',
#  '40.8194413,-81.4540733': 'area 3 near Canton, OH, United States',
#  '41.7663045,-88.1876676': 'area 2 near Naperville, IL, United States',
#  '41.7680818,-88.3044908': 'area 2 near Aurora, IL, United States',
#  '41.7700279,-88.3605603': 'area 1 near Aurora, IL, United States',
#  '41.7850937,-73.6940175': 'area 2 near Millbrook, NY, United States',
#  '41.7875713,-73.6771662': 'area 1 near Millbrook, NY, United States',
#  '41.9164343,-83.3977101': 'area 1 near Monroe, MI, United States',
#  '41.942386,-83.2690782': 'area 2 near Monroe, MI, United States',
#  '41.9524718,3.1272343': 'area 1 near Torrent, Spain',
#  '42.0212746,-93.6153476': 'area 1 near Ames, IA, United States',
#  '42.0307812,-93.6319131': 'area 2 near Ames, IA, United States',
#  '42.0745196,-78.4648536': 'area 1 near Olean, NY, United States',
#  '42.0986867,-75.9179738': 'area 2 near Binghamton, NY, United States',
#  '42.113105,-80.043846': 'area 2 near Erie, PA, United States',
#  '42.1182559,-78.415105': 'area 2 near Olean, NY, United States',
#  '42.1292241,-80.085059': 'area 1 near Erie, PA, United States',
#  '42.1352878,24.7453972': 'area 2 near Plovdiv, Bulgaria',
#  '42.1354079,24.7452904': 'area 1 near Plovdiv, Bulgaria',
#  '42.143127,-75.9433289': 'area 1 near Binghamton, NY, United States',
#  '42.23903,-71.739098': 'area 1 near Worcester, MA, United States',
#  '42.2625932,-71.8022934': 'area 2 near Worcester, MA, United States',
#  '42.2917069,-85.5872286': 'area 1 near Kalamazoo, MI, United States',
#  '42.2922891,-85.6935624': 'area 2 near Kalamazoo, MI, United States',
#  '42.4138139,-83.4690247': 'area 1 near Northville, MI, United States',
#  '42.4311464,-83.4832692': 'area 2 near Northville, MI, United States',
#  '42.4324668,-76.476676': 'area 2 near Ithaca, NY, United States',
#  '42.4439614,-76.5018807': 'area 1 near Ithaca, NY, United States',
#  '42.4704686,-90.660607': 'area 2 near Dubuque, IA, United States',
#  '42.5009509,-90.6644282': 'area 1 near Dubuque, IA, United States',
#  '42.5266085,-83.7905556': 'area 2 near Brighton, MI, United States',
#  '42.570309,-83.778': 'area 1 near Brighton, MI, United States',
#  '42.5847425,-87.8211854': 'area 2 near Kenosha, WI, United States',
#  '42.5987777,-83.9336047': 'area 2 near Howell, MI, United States',
#  '42.609138,-89.0116576': 'area 2 near Janesville, WI, United States',
#  '42.6404092,-87.9229611': 'area 1 near Kenosha, WI, United States',
#  '42.6525793,-73.7562317': 'area 1 near Albany, NY, United States',
#  '42.6827885,-89.0187222': 'area 1 near Janesville, WI, United States',
#  '42.6883891,-83.9492871': 'area 1 near Howell, MI, United States',
#  '42.7284117,-73.6917851': 'area 2 near Troy, NY, United States',
#  '42.7325225,-73.6294924': 'area 1 near Troy, NY, United States',
#  '42.732535,-84.5555347': 'area 2 near Lansing, MI, United States',
#  '42.7335857,-84.5157267': 'area 1 near Lansing, MI, United States',
#  '42.7429277,-73.8694034': 'area 2 near Albany, NY, United States',
#  '42.7482883,-73.8140654': 'area 3 near Albany, NY, United States',
#  '42.7734318,-73.9262467': 'area 4 near Schenectady, NY, United States',
#  '42.788285,-73.9247499': 'area 2 near Schenectady, NY, United States',
#  '42.8142432,-73.9395687': 'area 3 near Schenectady, NY, United States',
#  '42.8571807,-73.9320341': 'area 1 near Schenectady, NY, United States',
#  '42.8612109,-78.8184432': 'area 3 near Buffalo, NY, United States',
#  '42.8864468,-78.8783689': 'area 1 near Buffalo, NY, United States',
#  '42.8949017,-85.5090916': 'area 1 near Grand Rapids, MI, United States',
#  '42.9405299,-78.8697906': 'area 2 near Buffalo, NY, United States',
#  '42.941807,-83.8748112': 'area 1 near Swartz Creek, MI, United States',
#  '42.945805,-78.9017805': 'area 4 near Buffalo, NY, United States',
#  '42.9572508,-83.8305144': 'area 2 near Swartz Creek, MI, United States',
#  '42.9633599,-85.6680863': 'area 2 near Grand Rapids, MI, United States',
#  '43.0116784,-88.2314813': 'area 2 near Waukesha, WI, United States',
#  '43.0226221,-76.2221624': 'area 1 near Syracuse, NY, United States',
#  '43.0351807,-76.1742949': 'area 2 near Syracuse, NY, United States',
#  '43.0374792,-88.2339475': 'area 1 near Waukesha, WI, United States',
#  '43.0398856,-76.0750347': 'area 3 near Syracuse, NY, United States',
#  '43.0481221,-76.1474244': 'area 4 near Syracuse, NY, United States',
#  '43.0962143,-79.0377388': 'area 1 near Niagara Falls, NY, United States',
#  '43.100903,-75.232664': 'area 2 near Utica, NY, United States',
#  '43.106456,-76.2177046': 'area 1 near Liverpool, NY, United States',
#  '43.124563,-75.204123': 'area 1 near Utica, NY, United States',
#  '43.1275966,-79.0495505': 'area 2 near Niagara Falls, NY, United States',
#  '43.1346924,-77.5145906': 'area 2 near Rochester, NY, United States',
#  '43.1399802,-77.5914861': 'area 1 near Rochester, NY, United States',
#  '43.1497793,-77.6992407': 'area 3 near Rochester, NY, United States',
#  '43.1503063,-76.1813477': 'area 2 near Liverpool, NY, United States',
#  '43.1524699,-77.6311267': 'area 4 near Rochester, NY, United States',
#  '43.1527214,-77.630038': 'area 5 near Rochester, NY, United States',
#  '43.16103,-77.6109219': 'area 6 near Rochester, NY, United States',
#  '43.2267371,-77.5950827': 'area 7 near Rochester, NY, United States',
#  '43.5056093,-96.7297939': 'area 3 near Sioux Falls, SD, United States',
#  '43.5433774,-96.7624665': 'area 2 near Sioux Falls, SD, United States',
#  '43.5445959,-96.7311034': 'area 4 near Sioux Falls, SD, United States',
#  '43.5797334,-96.7580677': 'area 1 near Sioux Falls, SD, United States',
#  '43.5824275,-84.9193082': 'area 2 near Mount Pleasant, MI, United States',
#  '43.5966127,-84.4143296': 'area 1 near Midland, MI, United States',
#  '43.5978075,-84.7675139': 'area 1 near Mount Pleasant, MI, United States',
#  '43.6155825,-84.2472116': 'area 2 near Midland, MI, United States',
#  '43.7508284,-87.71453': 'area 1 near Sheboygan, WI, United States',
#  '43.8013556,-91.2395807': 'area 1 near La Crosse, WI, United States',
#  '43.8195836,-87.7755788': 'area 2 near Sheboygan, WI, United States',
#  '43.8443817,-91.2640189': 'area 2 near La Crosse, WI, United States',
#  '43.9228153,-88.5533361': 'area 1 near Oshkosh, WI, United States',
#  '43.9332109,-91.7300112': 'area 2 near Winona, MN, United States',
#  '43.9710332,-92.4637188': 'area 3 near Rochester, MN, United States',
#  '44.0121221,-92.4801989': 'area 1 near Rochester, MN, United States',
#  '44.0247062,-88.5426136': 'area 2 near Oshkosh, WI, United States',
#  '44.032423,-92.4208713': 'area 2 near Rochester, MN, United States',
#  '44.0553908,-91.6663523': 'area 1 near Winona, MN, United States',
#  '44.0710766,-103.134096': 'area 2 near Rapid City, SD, United States',
#  '44.078473,-103.21586': 'area 1 near Rapid City, SD, United States',
#  '44.2594275,-88.5110922': 'area 3 near Appleton, WI, United States',
#  '44.2619309,-88.4153847': 'area 2 near Appleton, WI, United States',
#  '44.3514142,-88.4553043': 'area 1 near Appleton, WI, United States',
#  '44.7630567,-85.6206317': 'area 1 near Traverse City, MI, United States',
#  '44.8046006,-91.4920071': 'area 2 near Eau Claire, WI, United States',
#  '44.8153225,-91.502931': 'area 1 near Eau Claire, WI, United States',
#  '44.9626772,-85.4878514': 'area 2 near Traverse City, MI, United States',
#  '45.5425567,-94.1090851': 'area 1 near Saint Cloud, MN, United States',
#  '45.5579451,-94.1632404': 'area 2 near Saint Cloud, MN, United States',
#  '46.0878165,-64.7782313': 'area 1 near Moncton, Canada',
#  '46.1535937,-64.7697901': 'area 2 near Moncton, Canada',
#  '46.7089299,-92.2079626': 'area 1 near Duluth, MN, United States',
#  '46.7571744,-96.8351569': 'area 2 near Fargo, ND, United States',
#  '46.7866719,-92.1004852': 'area 2 near Duluth, MN, United States',
#  '46.8023381,-100.7098828': 'area 3 near Bismarck, ND, United States',
#  '46.8092259,-100.8095211': 'area 2 near Bismarck, ND, United States',
#  '46.8672369,-100.854324': 'area 1 near Bismarck, ND, United States',
#  '46.8771863,-96.7898034': 'area 1 near Fargo, ND, United States',
#  '47.9249457,-97.0797206': 'area 1 near Grand Forks, ND, United States',
#  '47.9316964,-97.22365': 'area 2 near Grand Forks, ND, United States',
#  '48.2162072,-101.3221721': 'area 1 near Minot, ND, United States',
#  '48.2461469,-101.2991199': 'area 2 near Minot, ND, United States',
#  '48.4264828,-123.3234659': 'area 3 near Victoria, Canada',
#  '48.4284207,-123.3656444': 'area 1 near Victoria, Canada',
#  '48.4442943,-123.4297652': 'area 2 near Victoria, Canada',
#  '49.3092986,-123.064727': 'area 1 near North Vancouver, Canada',
#  '49.3269904,-123.0732801': 'area 2 near North Vancouver, Canada',
#  '49.45203,11.07675': 'area 1 near Nürnberg, Germany',
#  '49.4971202,11.079808': 'area 2 near Nürnberg, Germany',
#  '49.8879519,-119.4960106': 'area 1 near Kelowna, Canada',
#  '49.8887748,-119.4591495': 'area 2 near Kelowna, Canada',
#  '50.0379326,8.5621518': 'area 1 near Frankfurt am Main, Germany',
#  '50.1109221,8.6821267': 'area 2 near Frankfurt am Main, Germany',
#  '50.674522,-120.3272674': 'area 1 near Kamloops, Canada',
#  '50.6761328,-120.2411463': 'area 2 near Kamloops, Canada',
#  '51.4454012,-2.5456095': 'area 1 near Bristol, United Kingdom',
# 5271          NC     area 5 near Wilmington, NC, United States
# 5828          NC         area 1 near Wilson, NC, United States
# 5870          NC         area 2 near Wilson, NC, United States
# 1102     Windsor                area 1 near Windsor, Australia
# 1597     Windsor                area 2 near Windsor, Australia
# 11615         MN         area 1 near Winona, MN, United States
# 11542         MN         area 2 near Winona, MN, United States
# 6029          NC  area 1 near Winston-Salem, NC, United States
# 6033          NC  area 2 near Winston-Salem, NC, United States
# 6021          NC  area 3 near Winston-Salem, NC, United States
# 7097          VA     area 1 near Woodbridge, VA, United States
# 7106          VA     area 2 near Woodbridge, VA, United States
# 9275          NY       area 1 near Woodbury, NY, United States
# 8730          NY       area 2 near Woodbury, NY, United States
# 10044         MA      area 1 near Worcester, MA, United States
# 10068         MA      area 2 near Worcester, MA, United States
# 7959          PA           area 1 near York, PA, United States
# 7960          PA           area 2 near York, PA, United States
# 7979          PA           area 3 near York, PA, United States
#
# [629 rows x 6 columns]

# %% [markdown]
# **Finally, I noticed that there are still duplicated records for 6 pairs of coords. Must fix these:**

# %%
dupes = by_coords[by_coords.duplicated(subset = ["coords"], keep = False)].sort_values(by = "coords")
dupes
# Out:
#                        coords                           map_name  downloads  \
# 7016    38.5079606,-0.2285807  La Vila Joiosa/Villajoyosa, Spain          1
# 7017    38.5079606,-0.2285807                 Villajoyosa, Spain        255
# 12599  45.4895636,-73.8205567        Dollard-Des Ormeaux, Canada         16
# 12600  45.4895636,-73.8205567        Dollard-des-Ormeaux, Canada          6
# 12618   45.5016889,-73.567256                   Montreal, Canada      67897
# 12619   45.5016889,-73.567256                   Montréal, Canada      14438
# 12629  45.5125819,-73.6468307                 Mont-Royal, Canada         56
# 12630  45.5125819,-73.6468307                Mount Royal, Canada          2
# 21076    55.763516,12.4949429            Kongens Lyngby, Denmark          1
# 21077    55.763516,12.4949429                    Lyngby, Denmark        125
# 21629    60.1698557,24.938379               Helsingfors, Finland       5076
# 21630    60.1698557,24.938379                  Helsinki, Finland       4455
#
#                                                  top_doi        lat        lon
# 7016   http://dx.doi.org/10.1111/j.1875-595X.2011.000...  38.507961  -0.228581
# 7017   http://dx.doi.org/10.1111/j.1875-595X.2011.000...  38.507961  -0.228581
# 12599           http://dx.doi.org/10.1098/rspa.1984.0021  45.489564 -73.820557
# 12600           http://dx.doi.org/10.1098/rspa.1984.0021  45.489564 -73.820557
# 12618                http://dx.doi.org/10.1002/wnan.1317  45.501689 -73.567256
# 12619                http://dx.doi.org/10.1002/wnan.1317  45.501689 -73.567256
# 12629         http://dx.doi.org/10.1016/j.im.2008.05.002  45.512582 -73.646831
# 12630         http://dx.doi.org/10.1016/j.im.2008.05.002  45.512582 -73.646831
# 21076          http://dx.doi.org/10.1029/JD093iD08p09433  55.763516  12.494943
# 21077          http://dx.doi.org/10.1029/JD093iD08p09433  55.763516  12.494943
# 21629        http://dx.doi.org/10.1007/s41105-015-0027-5  60.169856  24.938379
# 21630        http://dx.doi.org/10.1007/s41105-015-0027-5  60.169856  24.938379

# %%
fixed_dupes = dupes[dupes.duplicated(subset = ["coords"], keep = "last")]
fixed_dupes = fixed_dupes.set_index("coords")
other = dupes[dupes.duplicated(subset = ["coords"], keep = "first")].set_index("coords")
fixed_dupes.downloads = fixed_dupes.downloads.add(other.downloads, fill_value = 0)
fixed_dupes
# Out:
#                                                  map_name  downloads  \
# coords
# 38.5079606,-0.2285807   La Vila Joiosa/Villajoyosa, Spain        256
# 45.4895636,-73.8205567        Dollard-Des Ormeaux, Canada         22
# 45.5016889,-73.567256                    Montreal, Canada      82335
# 45.5125819,-73.6468307                 Mont-Royal, Canada         58
# 55.763516,12.4949429              Kongens Lyngby, Denmark        126
# 60.1698557,24.938379                 Helsingfors, Finland       9531
#
#                                                                   top_doi  \
# coords
# 38.5079606,-0.2285807   http://dx.doi.org/10.1111/j.1875-595X.2011.000...
# 45.4895636,-73.8205567           http://dx.doi.org/10.1098/rspa.1984.0021
# 45.5016889,-73.567256                 http://dx.doi.org/10.1002/wnan.1317
# 45.5125819,-73.6468307         http://dx.doi.org/10.1016/j.im.2008.05.002
# 55.763516,12.4949429            http://dx.doi.org/10.1029/JD093iD08p09433
# 60.1698557,24.938379          http://dx.doi.org/10.1007/s41105-015-0027-5
#
#                               lat        lon
# coords
# 38.5079606,-0.2285807   38.507961  -0.228581
# 45.4895636,-73.8205567  45.489564 -73.820557
# 45.5016889,-73.567256   45.501689 -73.567256
# 45.5125819,-73.6468307  45.512582 -73.646831
# 55.763516,12.4949429    55.763516  12.494943
# 60.1698557,24.938379    60.169856  24.938379

# %%
len(by_coords)
# Out:
# 23701

# %%
by_coords = by_coords.drop(dupes.index)
len(by_coords)
# Out:
# 23689

# %%
by_coords = by_coords.set_index("coords")
by_coords = by_coords.append(fixed_dupes)
len(by_coords)
# Out:
# 23695

# %% [markdown]
# **Ready for mapping!**

# %% [markdown]
# **Finally, let's do some frequency analysis...**

# %%
def get_days(month):
    filepath = "scihub_data/" + month + ".tab"
    with open(filepath, "r") as f:
        data = pd.read_table(f)
        data.columns = ["date","doi","IP_code","country","city","coords"]
        data = data[["date","doi"]]
        data.date = pd.to_datetime(data.date).apply(lambda x: "%s-%s-%s" %(x.year, x.month, x.day))
        data = data.groupby("date").count()
        data = data.reset_index()
        data = data.rename(columns = {"doi":"downloads"})
        return data

# %%
by_day = pd.concat([get_days(month) for month in months])
by_day = by_day.groupby("date").sum()
by_day.to_csv("downloads_by_day.csv")

# %%
by_day = by_day[:164]
by_day.tail()
# Out:
#          date  downloads
# 159  2016-2-5     178126
# 160  2016-2-6     143356
# 161  2016-2-7     123561
# 162  2016-2-8     184710
# 163  2016-2-9     187652

# %%
by_day["day"] = pd.to_datetime(by_day.date).apply(lambda x: x.isoweekday())
by_day.head()
# Out:
#          date  downloads  day
# 0   2015-10-1     163758    4
# 1  2015-10-10     175451    6
# 2  2015-10-11     164789    7
# 3  2015-10-12     241172    1
# 4  2015-10-13     238358    2

# %%
# %matplotlib inline

by_day.groupby("day").sum().downloads.plot(kind="bar")

# %% [markdown]
# **TUESDAY is the busiest day for Sci-Hub. Well how about that?**
